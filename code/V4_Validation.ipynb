# %%
import pandas as pd
import geopandas as gpd
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import matplotlib.ticker as ticker
from matplotlib.cm import ScalarMappable
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

import pickle

from math import radians, cos, sin, sqrt, atan2

from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import r2_score
from sklearn.metrics import d2_absolute_error_score
from sklearn.metrics import mean_squared_error
# from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score
from sklearn.metrics import max_error
from sklearn.model_selection import cross_validate
from sklearn.model_selection import KFold
from sklearn.cluster import KMeans
from sklearn.cluster import HDBSCAN
from sklearn.cluster import AgglomerativeClustering
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from matplotlib.colors import Normalize
from matplotlib.colors import ListedColormap

import cartopy.crs as ccrs
import cartopy.feature as cfeature

import random

import libpysal as lp
from libpysal.weights import DistanceBand
from esda.moran import Moran

# from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.basemap import Basemap

# For sanity checking
from sklearn.decomposition import PCA

from sklearn.inspection import permutation_importance
from sklearn.inspection import PartialDependenceDisplay

from scipy.stats import norm
from scipy.stats import kurtosis
from scipy.stats import gaussian_kde
from scipy.spatial.distance import cdist

import glob

from geopy.distance import geodesic

from joblib import dump, load
from tqdm.notebook import tqdm

import os
import shutil
import pysplit

# These packages are used when the code to plot the decision tree is uncommented
# See **TREE PLOTTING** section and un-uncomment the code there
from sklearn.tree import plot_tree
from sklearn.tree import export_text

import warnings
from geopy.distance import geodesic

# import umap
from geopy.distance import great_circle
from joblib import Parallel, delayed
# from haversine import haversine, Unit
# from numba import jit
from functools import reduce

# plt.ioff()

# %%
# Define a function that calcualte error metrics from predicted and actual values
def reg_model_metrics(actual,pred):
    MSE = mean_squared_error(actual,pred)
    RMSE = np.sqrt(MSE)
    actual_mean = np.mean(actual)
    RRMSE = 100*RMSE/actual_mean
    MAE = mean_absolute_error(actual, pred)
    R2 = r2_score(actual,pred)
    D2 = d2_absolute_error_score(actual, pred)
    MAXErr = max_error(actual, pred)
    EVS = explained_variance_score(actual, pred)
    return MSE, RMSE, RRMSE, MAE, R2, D2, MAXErr, EVS 

def calculate_and_organize_metrics_model(actual, pred, model, ats):
     
    # Calculate standard error metrics
    mse, rmse, rrmse, mae, r2, d2, max_err, evs = reg_model_metrics(actual, pred)
    
    # Organize metrics into a dictionary
    metrics_dict = {
        "Model": model,
        "ATS" : ats,
        f"MSE": mse,
        f"RMSE": rmse,
        f"RRMSE": rrmse,
        f"MAE": mae,
        f"R2": r2,
        f"D2": d2,
        f"MaxErr": max_err,
        f"EVS": evs,
    }
    
    # Convert dictionary to DataFrame
    metrics_df = pd.DataFrame(metrics_dict, index=[0])
   
    return metrics_df

def scatter_plot(actual, pred, title, var_of_int, save_path):
    # Color Matching for clarity
    if var_of_int == 'CH4':
        color = 'blue'
        cm = 'Blues'
    elif var_of_int == 'DMS':
        color = 'purple'
        cm = 'Purples'
    elif var_of_int == 'CO':
        color = 'cyan'
        cm = 'YlGnBu'
    elif var_of_int == 'O3':
        color = 'gold'
        cm = 'YlOrBr'
    elif var_of_int == 'Benzene':
        color = 'red'
        cm = 'Reds'
    elif var_of_int == 'CH3Br':
        color = 'mediumseagreen'
        cm = 'Greens'
    elif var_of_int == 'Ethane':
        color = 'orange'
        cm = 'Oranges'
    else:
        color = 'gray'
        cm = 'Greys'
        
    # if comp_flag:
    #     cm = "Greys"
    
    MSE, RMSE, RRMSE, MAE, R2, D2, MAXErr, EVS = reg_model_metrics(actual, pred)
        
    fig,ax = plt.subplots(figsize=(8, 6))
    ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
    ax.plot([actual.min(), actual.max()], [actual.min(), actual.max()], 'r--', lw=2)
    # text = r"R2 = %.2f" % (R2); text += "\n";
    # text += r"D2 = %.2f" % (D2); text += "\n";
    text = r"MAE = %.2f" % (MAE); text += "\n";
    text += r"RMSE = %.2f" % (RMSE); text += "\n";
    text += r"MSE = %.2f" % (MSE);     
    plt.annotate(text, xy=(0.01, 0.9), xycoords='axes fraction',color='black', fontsize=10,bbox=dict(facecolor='none', edgecolor='none'))
    ax.set_xlabel(f'Measured {var_of_int}')
    ax.set_ylabel(f'Predicted {var_of_int}')
    # Set log scale for x and y axes
    ax.set_xscale('log')
    ax.set_yscale('log')
    # if var_of_int != 'DMS':
    # Create locators to specify the ticks on both axes
    ax.xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=10))  # Controls major ticks
    ax.xaxis.set_minor_locator(ticker.LogLocator(base=10.0, subs="auto"))  # Controls minor ticks

    ax.yaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=10))
    ax.yaxis.set_minor_locator(ticker.LogLocator(base=10.0, subs="auto"))

    # Ensure minor gridlines are visible and major gridlines are configured
    ax.grid(visible=True, which="major", linestyle="--", linewidth=0.5)  # Major gridlines
    ax.grid(visible=True, which="minor", linestyle=":", linewidth=0.5)  # Minor gridlines
    ax.set_title(title)
    # plt.grid()
    plt.savefig(save_path)
    # plt.show()
    plt.clf()
    return None

# %%
df = pd.read_csv(r"C:\Users\vwgei\Documents\PVOCAL\data\V4\df_preprocessed.csv")
atom_gmi = pd.read_csv(r"C:\Users\vwgei\Documents\PVOCAL\data\V4\joined_model_data\atom_gmi.csv")
atom_cesm = pd.read_csv(r"C:\Users\vwgei\Documents\PVOCAL\data\V4\joined_model_data\atom_cesm.csv")
seac4rs = pd.read_csv(r"C:\Users\vwgei\Documents\PVOCAL\data\V4\joined_model_data\seac4rs_geos-chem.csv")
winter = pd.read_csv(r"C:\Users\vwgei\Documents\PVOCAL\data\V4\joined_model_data\winter_geos-chem.csv")
korusaq = pd.read_csv(r"C:\Users\vwgei\Documents\PVOCAL\data\V4\joined_model_data\korusaq_micp.csv")

# %%
atom_gmi_df = pd.merge(atom_gmi, df, how='inner', on='iindex', suffixes=("_gmi", "_df"))
atom_cesm_df = pd.merge(atom_cesm, df, how='inner', on='iindex', suffixes=("_cesm", "_df"))
seac4rs_df = pd.merge(seac4rs, df, how='inner', on='iindex', suffixes=("_seac4rs", "_df"))
winter_df = pd.merge(winter, df, how='inner', on='iindex', suffixes=("_winter", "_df"))
korusaq_df = pd.merge(korusaq, df, how='inner', on='iindex', suffixes=("_korusaq", "_df"))

# %%
with open(r"C:\Users\vwgei\Documents\PVOCAL\ensemble_working\global_models\V4_CO\data\CO_global_X_test.pkl", 'rb') as file:
    co_test = pickle.load(file)
co_pred_test = np.load(r"C:\Users\vwgei\Documents\PVOCAL\ensemble_working\PASTEL_combined\V4_CO\CO_PASTEL_combined_pred_test.npy")

pastel_co = pd.DataFrame({
    "iindex": co_test.index,
    "PASTEL_CO": co_pred_test
})


with open(r"C:\Users\vwgei\Documents\PVOCAL\ensemble_working\global_models\V4_CH4\data\CH4_global_X_test.pkl", 'rb') as file:
    ch4_test = pickle.load(file)
ch4_pred_test = np.load(r"C:\Users\vwgei\Documents\PVOCAL\ensemble_working\PASTEL_combined\V4_CH4\CH4_PASTEL_combined_pred_test.npy")

pastel_ch4 = pd.DataFrame({
    "iindex": ch4_test.index,
    "PASTEL_CH4": ch4_pred_test
})


with open(r"C:\Users\vwgei\Documents\PVOCAL\ensemble_working\global_models\V4_CH3Br\data\CH3Br_global_X_test.pkl", 'rb') as file:
    ch3br_test = pickle.load(file)
ch3br_pred_test = np.load(r"C:\Users\vwgei\Documents\PVOCAL\ensemble_working\PASTEL_combined\V4_CH3Br\CH3Br_PASTEL_combined_pred_test.npy")

pastel_ch3br = pd.DataFrame({
    "iindex": ch3br_test.index,
    "PASTEL_CH3Br": ch3br_pred_test
})


with open(r"C:\Users\vwgei\Documents\PVOCAL\ensemble_working\global_models\V4_DMS\data\DMS_global_X_test.pkl", 'rb') as file:
    dms_test = pickle.load(file)
dms_pred_test = np.load(r"C:\Users\vwgei\Documents\PVOCAL\ensemble_working\PASTEL_combined\V4_DMS\DMS_PASTEL_combined_pred_test.npy")

pastel_dms = pd.DataFrame({
    "iindex": dms_test.index,
    "PASTEL_DMS": dms_pred_test
})


with open(r"C:\Users\vwgei\Documents\PVOCAL\ensemble_working\global_models\V4_Ethane\data\Ethane_global_X_test.pkl", 'rb') as file:
    ethane_test = pickle.load(file)
ethane_pred_test = np.load(r"C:\Users\vwgei\Documents\PVOCAL\ensemble_working\PASTEL_combined\V4_Ethane\Ethane_PASTEL_combined_pred_test.npy")

pastel_ethane = pd.DataFrame({
    "iindex": ethane_test.index,
    "PASTEL_Ethane": ethane_pred_test
})


with open(r"C:\Users\vwgei\Documents\PVOCAL\ensemble_working\global_models\V4_O3\data\O3_global_X_test.pkl", 'rb') as file:
    o3_test = pickle.load(file)
o3_pred_test = np.load(r"C:\Users\vwgei\Documents\PVOCAL\ensemble_working\PASTEL_combined\V4_O3\O3_PASTEL_combined_pred_test.npy")

pastel_o3 = pd.DataFrame({
    "iindex": o3_test.index,
    "PASTEL_O3": o3_pred_test
})

# %%
# List of DataFrames to merge
dfs = [pastel_co, pastel_ch4, pastel_ethane, pastel_dms, pastel_ch3br, pastel_o3]

# Merge all DataFrames on 'iindex' using outer join
pastel = reduce(lambda left, right: pd.merge(left, right, how="outer", on="iindex"), dfs)

# %%
pastel
# Out:
#        iindex   PASTEL_CO  PASTEL_CH4  PASTEL_Ethane  PASTEL_DMS  \
# 0       21026  230.802942         NaN            NaN         NaN
# 1        7283  116.191180         NaN            NaN         NaN
# 2         612   60.258867         NaN            NaN         NaN
# 3       33869  387.163510         NaN            NaN    12.99987
# 4       38732   57.658160         NaN            NaN         NaN
# ...       ...         ...         ...            ...         ...
# 29876   35394         NaN         NaN            NaN         NaN
# 29877   35827         NaN         NaN            NaN         NaN
# 29878   25088         NaN         NaN            NaN         NaN
# 29879   22539         NaN         NaN            NaN         NaN
# 29880   14932         NaN         NaN            NaN         NaN
#
#        PASTEL_CH3Br  PASTEL_O3
# 0               NaN        NaN
# 1               NaN        NaN
# 2               NaN        NaN
# 3               NaN        NaN
# 4               NaN        NaN
# ...             ...        ...
# 29876           NaN  50.291097
# 29877           NaN  55.950217
# 29878           NaN  51.205646
# 29879           NaN  46.140839
# 29880           NaN  54.227944
#
# [29881 rows x 7 columns]

# %%
atom_gmi_f = pd.merge(atom_gmi_df, pastel, how='inner', on='iindex')
atom_cesm_f = pd.merge(atom_cesm_df, pastel, how='inner', on='iindex')
seac4rs_f = pd.merge(seac4rs_df, pastel, how='inner', on='iindex')
winter_f = pd.merge(winter_df, pastel, how='inner', on='iindex')
korusaq_f = pd.merge(korusaq_df, pastel, how='inner', on='iindex')

final_dfs = [atom_gmi_f,atom_cesm_f,seac4rs_f,winter_f,korusaq_f]

for df in final_dfs:
    # Replace WAS nodata value with np.nan for consistency
    df.replace(-999999.0, np.nan, inplace=True)
    df.replace(-888888.0, np.nan, inplace=True)
    df.replace(-888888888.0, np.nan, inplace=True)
    df.replace(-999999999.0, np.nan, inplace=True)
    df.replace(-99999.000000, np.nan, inplace=True)
    df.replace(-999.990000, np.nan, inplace=True)
    df.replace(-9.999999e+09, np.nan, inplace=True)
    df.replace(-9.999990e+08, np.nan, inplace=True)
    df.replace(-8.888888e+06, np.nan, inplace=True)
    df.replace(-9.999999e+06, np.nan, inplace=True)

    # Replace WAS nodata value with np.nan for consistency
    df.replace(-8888, np.nan, inplace=True)
    df.replace(-999, np.nan, inplace=True)
    df.replace(-888, np.nan, inplace=True)
    df.replace(-777, np.nan, inplace=True)
    df.replace(-777.770000, np.nan, inplace=True)
    df.replace(-888.800000, np.nan, inplace=True)
    df.replace(-888.880000, np.nan, inplace=True)
    df.replace(10000000, np.nan, inplace=True)

# %%
atom_gmi_f["GMI_Ethane_GMI"] = atom_gmi_f["GMI_Ethane_GMI"] * 1e3

# %%
atom_gmi_f["GMI_CH3Br_GMI"] = atom_gmi_f["GMI_CH3Br_GMI"] * 1e3

# %%
ATS_names = ["CO", "CH4", "CH3Br", "DMS", "O3", "Ethane"]

# Create a mapping of names to specific column names for the GMI and PASTEL models
model_mapping = {
    "CO": ("CO_df", "GMI_CO_GMI", "PASTEL_CO"),
    "CH3Br": ("CH3Br", "GMI_CH3Br_GMI", "PASTEL_CH3Br"),
    "CH4": ("CH4_df", "GMI_CH4_GMI", "PASTEL_CH4"),
    "Ethane": ("Ethane", "GMI_Ethane_GMI", "PASTEL_Ethane"),
    "O3": ("O3_df", "GMI_O3_GMI", "PASTEL_O3"),
}

# Initialize an empty list to store results
metrics_list = []

# Loop through species and calculate metrics
for species, (data_col, gmi_col, pastel_col) in model_mapping.items():
    # Drop NaN values from both data and target columns
    merged_gmi = pd.concat([atom_gmi_f[data_col], atom_gmi_f[gmi_col]], axis=1).dropna()
    merged_pastel = pd.concat([atom_gmi_f[data_col], atom_gmi_f[pastel_col]], axis=1).dropna()
    
    # Ensure the same rows are kept in both DataFrames (i.e., intersection of indexes)
    merged_gmi = merged_gmi.loc[merged_gmi.index.intersection(merged_pastel.index)]
    
    # scatter_plot(merged_gmi[data_col], merged_gmi[gmi_col], "gmi_scatter", species)
    # scatter_plot(merged_pastel[data_col], merged_pastel[pastel_col], "pastel_sctter", species)

    # Calculate metrics for GMI and PASTEL after dropping NaN
    metrics_list.append(
        calculate_and_organize_metrics_model(merged_gmi[data_col], merged_gmi[gmi_col], "GMI", species)
    )
    metrics_list.append(
        calculate_and_organize_metrics_model(merged_pastel[data_col], merged_pastel[pastel_col], "PASTEL", species)
    )

# Combine all metrics into a single DataFrame
model_metrics = pd.concat(metrics_list, ignore_index=True)

model_metrics[['Model', 'ATS', 'RMSE', 'MAE', "R2"]]

# ATS_names = ["CO", "CH4", "CH3Br", "DMS", "O3", "Ethane"]

# gmi_co = calculate_and_organize_metrics_model(atom_gmi_f['CO_df'], atom_gmi_f['GMI_CO_GMI'], "GMI", "CO")
# gmi_ch3br = calculate_and_organize_metrics_model(atom_gmi_f['CH3Br'], atom_gmi_f['GMI_CH3Br_GMI'], "GMI", "CH3Br")
# gmi_ch4 = calculate_and_organize_metrics_model(atom_gmi_f['CH4_df'], atom_gmi_f['GMI_CH4_GMI'], "GMI", "CH4")
# gmi_ethane = calculate_and_organize_metrics_model(atom_gmi_f['Ethane'], atom_gmi_f['GMI_Ethane_GMI'], "GMI", "C2H6")
# gmi_o3 = calculate_and_organize_metrics_model(atom_gmi_f['O3'], atom_gmi_f['GMI_O3_GMI'], "GMI", "O3")
# pastel_co = calculate_and_organize_metrics_model(atom_gmi_f['CO_df'], atom_gmi_f['PASTEL_CO'], "PASTEL", "CO")
# pastel_ch3br = calculate_and_organize_metrics_model(atom_gmi_f['CH3Br'], atom_gmi_f['PASTEL_CH3Br'], "PASTEL", "CH3Br")
# pastel_ch4 = calculate_and_organize_metrics_model(atom_gmi_f['CH4_df'], atom_gmi_f['PASTEL_CH4'], "PASTEL", "CH4")
# pastel_ethane = calculate_and_organize_metrics_model(atom_gmi_f['Ethane'], atom_gmi_f['PASTEL_Ethane'], "PASTEL", "C2H6")
# pastel_o3 = calculate_and_organize_metrics_model(atom_gmi_f['O3'], atom_gmi_f['PASTEL_O3'], "PASTEL", "O3")


# model_metrics = pd.concat([gmi_co, pastel_co, 
#                            gmi_ch3br, pastel_ch3br, 
#                            gmi_ch4, pastel_ch4, 
#                            gmi_ethane, pastel_ethane,
#                            gmi_o3, pastel_o3], ignore_index=True)
# Out:
#     Model     ATS        RMSE         MAE         R2
# 0     GMI      CO   20.121550   15.084427   0.576432
# 1  PASTEL      CO   11.530789    7.110605   0.860903
# 2     GMI   CH3Br    5.171760    5.126703 -72.106628
# 3  PASTEL   CH3Br    0.387029    0.269500   0.590582
# 4     GMI     CH4   26.528310   21.700120   0.742828
# 5  PASTEL     CH4   13.855175    8.643548   0.929850
# 6     GMI  Ethane  399.624985  180.277357   0.572089
# 7  PASTEL  Ethane  230.985029  109.462410   0.857040
# 8     GMI      O3   28.101071   12.733067   0.901025
# 9  PASTEL      O3   28.361160   11.933836   0.899185

# %%
for c in atom_cesm_f.columns:
    print(c)
# Out:
# iindex
# Datetime_cesm
# MMS_P
# MMS_T
# MMS_TAS
# U
# V
# W
# MMS_TEDR
# MMS_REYN
# LAT_cesm
# LON_cesm
# ALT_cesm
# MMS_POT
# MMS_ROLL
# MMS_HDG
# MMS_PITCH
# MMS_YAW
# MMS_AOA
# DLH_H2O_H2O_DLH
# DLH_H2O_RHi_DLH
# DLH_H2O_RHw_DLH
# ATHOS_OHI_OHInterference_ATHOS
# OH
# ATHOS_HOx_HO2_ATHOS
# ATHOS_OHR_T_OHR
# ATHOS_OHR_P_OHR
# ATHOS_OHR_OHReactivity_OHR
# Influences_Julian_Day
# Influences_Lat
# Influences_Lon
# Influences_Pres
# Influences_Prob_ConvInf
# Influences_Prob_ConvInf_Land
# Influences_ConvInf_CldTop
# Influences_Days_Since_ConvInf
# Influences_Days_Since_Most_Recent_ConvInf
# Influences_Prob_BdyInf
# Influences_Days_Since_BdyInf_Most_Recent
# Influences_Days_Since_BdyInf_All
# Influences_Prob_Land_BdyInf
# Influences_Days_Since_Land_BdyInf_Most_Recent
# Influences_Prob_SeaIceInf
# Influences_Prob_StratInf
# Influences_Days_Since_StratInf_Most_Recent
# Influences_Days_Since_StratInf_All
# Influences_Prob_FireInf
# Influences_Days_Since_FireInf_Most_Recent
# Influences_Days_Since_FireInf_All
# Influences_Sunlight_Exposure
# CO2_cesm
# CH4_cesm
# CO_cesm
# GMI_lat
# GMI_lon
# GMI_StaticPressure_GMI
# GMI_TroposphereIndicator_GMI
# GMI_StaticTemperature_GMI
# GMI_CH2O_GMI
# GMI_CH4_GMI
# GMI_CO_GMI
# GMI_H2_GMI
# GMI_CHOOH_GMI
# GMI_HNO3_GMI
# GMI_HNO4_GMI
# GMI_H2O_GMI
# GMI_HO2_GMI
# GMI_H2O2_GMI
# GMI_CH3OH_GMI
# GMI_CH3OOH_GMI
# GMI_N2O_GMI
# GMI_NO_GMI
# GMI_NO2_GMI
# GMI_N2O5_GMI
# GMI_O3_GMI
# GMI_OH_GMI
# GMI_CH3Br_GMI
# GMI_CH3Cl_GMI
# GMI_CFC11_GMI
# GMI_CFC12_GMI
# GMI_CFC113_GMI
# GMI_CFC114_GMI
# GMI_CFC115_GMI
# GMI_HCFC22_GMI
# GMI_HCFC141b_GMI
# GMI_HCFC142b_GMI
# GMI_H1202_GMI
# GMI_H1211_GMI
# GMI_H1301_GMI
# GMI_H2402_GMI
# GMI_CH3CHO_GMI
# GMI_C4-C5Alkanes_GMI
# GMI_Ethane_GMI
# GMI_Propane_GMI
# GMI_Ethanol_GMI
# GMI_C2H5OOH_GMI
# GMI_Isoprene_GMI
# GMI_MAC_GMI
# GMI_CH3CO3_GMI
# GMI_MEK_GMI
# GMI_MVK_GMI
# GMI_PAN_GMI
# GMI_MPAN_GMI
# GMI_PPN_GMI
# GMI_Propene_GMI
# GMI_C4andC5Alkylnitrates_GMI
# GMI_C3toCnAldehydes_GMI
# GMI_Acetone_GMI
# Hskping_Day_Of_Year
# Hskping_Latitude
# Hskping_Longitude
# Hskping_MSL_GPS_Altitude
# Hskping_HAE_GPS_Altitude
# Hskping_Pressure_Altitude
# Hskping_Radar_Altitude
# Hskping_Ground_Speed
# Hskping_True_Air_Speed
# Hskping_Indicated_Air_Speed
# Hskping_Mach_Number
# Hskping_Vertical_Speed
# Hskping_True_Heading
# Hskping_Track_Angle
# Hskping_Drift_Angle
# Hskping_Pitch_Angle
# Hskping_Roll_Angle
# Hskping_Static_Air_Temp
# Hskping_Potential_Temp
# Hskping_Dew_Point
# Hskping_Total_Air_Temp
# Hskping_IR_Surf_Temp
# Hskping_Static_Pressure
# Hskping_Cabin_Pressure
# WNS
# WND
# Hskping_Solar_Zenith_Angle
# Hskping_Aircraft_Sun_Elevation
# Hskping_Sun_Azimuth
# Hskping_Aircraft_Sun_Azimuth
# Hskping_Mixing_Ratio
# Hskping_Part_Press_Water_Vapor
# Hskping_Sat_Vapor_Press_H2O
# Hskping_Sat_Vapor_Press_Ice
# Hskping_Relative_Humidity
# O3_cesm
# UCATS_O3_O3e_UCATS
# WAS_OCS_WAS
# DMS_cesm
# WAS_CFC12_WAS
# WAS_CFC11_WAS
# WAS_CFC113_WAS
# WAS_CFC114_WAS
# WAS_HFC152a_WAS
# WAS_HFC134a_WAS
# WAS_HFC365mfc_WAS
# WAS_HCFC124_WAS
# WAS_HCFC22_WAS
# WAS_HCFC142b_WAS
# WAS_HCFC141b_WAS
# WAS_H1301_WAS
# WAS_H2402_WAS
# WAS_H1211_WAS
# WAS_CH3CCl3_WAS
# WAS_CCl4_WAS
# WAS_CHCl3_WAS
# WAS_CH2Cl2_WAS
# WAS_C2Cl4_WAS
# WAS_CH3Cl_WAS
# CH3Br_cesm
# WAS_CH3I_WAS
# WAS_CH2Br2_WAS
# WAS_CHBrCl2_WAS
# WAS_CHBr2Cl_WAS
# CHBr3_WAS
# WAS_CH2ClCH2Cl_WAS
# WAS_MeONO2_WAS
# WAS_EthONO2_WAS
# WAS_iPropONO2_WAS
# WAS_nPropONO2_WAS
# WAS_x2ButONO2_WAS
# WAS_x3PentONO2_WAS
# WAS_x2PentONO2_WAS
# WAS_x3Me2ButONO2_WAS
# Ethane_cesm
# WAS_Ethene_WAS
# WAS_Ethyne_WAS
# WAS_Propane_WAS
# WAS_Propene_WAS
# WAS_iButane_WAS
# WAS_nButane_WAS
# WAS_iPentane_WAS
# WAS_nPentane_WAS
# WAS_Isoprene_WAS
# WAS_nHexane_WAS
# WAS_nHeptane_WAS
# WAS_x2MePentane_WAS
# WAS_x3MePentane_WAS
# WAS_Benzene_WAS
# WAS_Toluene_WAS
# WAS_EthBenzene_WAS
# WAS_mpXylene_WAS
# WAS_oXylene_WAS
# Pressure_-24_cesm
# Potential_Temperature_-24_cesm
# Temperature_-24_cesm
# Rainfall_-24_cesm
# Mixing_Depth_-24_cesm
# Relative_Humidity_-24_cesm
# Specific_Humidity_-24_cesm
# Mixing_Ratio_-24_cesm
# Terrain_Altitude_-24_cesm
# Solar_Radiation_-24_cesm
# geometry_-24_cesm
# DateTime_-24_cesm
# Temperature_C_-24_cesm
# Distance_ptp_-24_cesm
# Cumulative_Dist_-24_cesm
# Dist_from_origin_-24_cesm
# bearings_from_origin_-24_cesm
# bearings_ptp_-24_cesm
# Moisture_Flux_-24_cesm
# Pressure_-23_cesm
# Potential_Temperature_-23_cesm
# Temperature_-23_cesm
# Rainfall_-23_cesm
# Mixing_Depth_-23_cesm
# Relative_Humidity_-23_cesm
# Specific_Humidity_-23_cesm
# Mixing_Ratio_-23_cesm
# Terrain_Altitude_-23_cesm
# Solar_Radiation_-23_cesm
# geometry_-23_cesm
# DateTime_-23_cesm
# Temperature_C_-23_cesm
# Distance_ptp_-23_cesm
# Cumulative_Dist_-23_cesm
# Dist_from_origin_-23_cesm
# bearings_from_origin_-23_cesm
# bearings_ptp_-23_cesm
# Moisture_Flux_-23_cesm
# Pressure_-22_cesm
# Potential_Temperature_-22_cesm
# Temperature_-22_cesm
# Rainfall_-22_cesm
# Mixing_Depth_-22_cesm
# Relative_Humidity_-22_cesm
# Specific_Humidity_-22_cesm
# Mixing_Ratio_-22_cesm
# Terrain_Altitude_-22_cesm
# Solar_Radiation_-22_cesm
# geometry_-22_cesm
# DateTime_-22_cesm
# Temperature_C_-22_cesm
# Distance_ptp_-22_cesm
# Cumulative_Dist_-22_cesm
# Dist_from_origin_-22_cesm
# bearings_from_origin_-22_cesm
# bearings_ptp_-22_cesm
# Moisture_Flux_-22_cesm
# Pressure_-21_cesm
# Potential_Temperature_-21_cesm
# Temperature_-21_cesm
# Rainfall_-21_cesm
# Mixing_Depth_-21_cesm
# Relative_Humidity_-21_cesm
# Specific_Humidity_-21_cesm
# Mixing_Ratio_-21_cesm
# Terrain_Altitude_-21_cesm
# Solar_Radiation_-21_cesm
# geometry_-21_cesm
# DateTime_-21_cesm
# Temperature_C_-21_cesm
# Distance_ptp_-21_cesm
# Cumulative_Dist_-21_cesm
# Dist_from_origin_-21_cesm
# bearings_from_origin_-21_cesm
# bearings_ptp_-21_cesm
# Moisture_Flux_-21_cesm
# Pressure_-20_cesm
# Potential_Temperature_-20_cesm
# Temperature_-20_cesm
# Rainfall_-20_cesm
# Mixing_Depth_-20_cesm
# Relative_Humidity_-20_cesm
# Specific_Humidity_-20_cesm
# Mixing_Ratio_-20_cesm
# Terrain_Altitude_-20_cesm
# Solar_Radiation_-20_cesm
# geometry_-20_cesm
# DateTime_-20_cesm
# Temperature_C_-20_cesm
# Distance_ptp_-20_cesm
# Cumulative_Dist_-20_cesm
# Dist_from_origin_-20_cesm
# bearings_from_origin_-20_cesm
# bearings_ptp_-20_cesm
# Moisture_Flux_-20_cesm
# Pressure_-19_cesm
# Potential_Temperature_-19_cesm
# Temperature_-19_cesm
# Rainfall_-19_cesm
# Mixing_Depth_-19_cesm
# Relative_Humidity_-19_cesm
# Specific_Humidity_-19_cesm
# Mixing_Ratio_-19_cesm
# Terrain_Altitude_-19_cesm
# Solar_Radiation_-19_cesm
# geometry_-19_cesm
# DateTime_-19_cesm
# Temperature_C_-19_cesm
# Distance_ptp_-19_cesm
# Cumulative_Dist_-19_cesm
# Dist_from_origin_-19_cesm
# bearings_from_origin_-19_cesm
# bearings_ptp_-19_cesm
# Moisture_Flux_-19_cesm
# Pressure_-18_cesm
# Potential_Temperature_-18_cesm
# Temperature_-18_cesm
# Rainfall_-18_cesm
# Mixing_Depth_-18_cesm
# Relative_Humidity_-18_cesm
# Specific_Humidity_-18_cesm
# Mixing_Ratio_-18_cesm
# Terrain_Altitude_-18_cesm
# Solar_Radiation_-18_cesm
# geometry_-18_cesm
# DateTime_-18_cesm
# Temperature_C_-18_cesm
# Distance_ptp_-18_cesm
# Cumulative_Dist_-18_cesm
# Dist_from_origin_-18_cesm
# bearings_from_origin_-18_cesm
# bearings_ptp_-18_cesm
# Moisture_Flux_-18_cesm
# Pressure_-17_cesm
# Potential_Temperature_-17_cesm
# Temperature_-17_cesm
# Rainfall_-17_cesm
# Mixing_Depth_-17_cesm
# Relative_Humidity_-17_cesm
# Specific_Humidity_-17_cesm
# Mixing_Ratio_-17_cesm
# Terrain_Altitude_-17_cesm
# Solar_Radiation_-17_cesm
# geometry_-17_cesm
# DateTime_-17_cesm
# Temperature_C_-17_cesm
# Distance_ptp_-17_cesm
# Cumulative_Dist_-17_cesm
# Dist_from_origin_-17_cesm
# bearings_from_origin_-17_cesm
# bearings_ptp_-17_cesm
# Moisture_Flux_-17_cesm
# Pressure_-16_cesm
# Potential_Temperature_-16_cesm
# Temperature_-16_cesm
# Rainfall_-16_cesm
# Mixing_Depth_-16_cesm
# Relative_Humidity_-16_cesm
# Specific_Humidity_-16_cesm
# Mixing_Ratio_-16_cesm
# Terrain_Altitude_-16_cesm
# Solar_Radiation_-16_cesm
# geometry_-16_cesm
# DateTime_-16_cesm
# Temperature_C_-16_cesm
# Distance_ptp_-16_cesm
# Cumulative_Dist_-16_cesm
# Dist_from_origin_-16_cesm
# bearings_from_origin_-16_cesm
# bearings_ptp_-16_cesm
# Moisture_Flux_-16_cesm
# Pressure_-15_cesm
# Potential_Temperature_-15_cesm
# Temperature_-15_cesm
# Rainfall_-15_cesm
# Mixing_Depth_-15_cesm
# Relative_Humidity_-15_cesm
# Specific_Humidity_-15_cesm
# Mixing_Ratio_-15_cesm
# Terrain_Altitude_-15_cesm
# Solar_Radiation_-15_cesm
# geometry_-15_cesm
# DateTime_-15_cesm
# Temperature_C_-15_cesm
# Distance_ptp_-15_cesm
# Cumulative_Dist_-15_cesm
# Dist_from_origin_-15_cesm
# bearings_from_origin_-15_cesm
# bearings_ptp_-15_cesm
# Moisture_Flux_-15_cesm
# Pressure_-14_cesm
# Potential_Temperature_-14_cesm
# Temperature_-14_cesm
# Rainfall_-14_cesm
# Mixing_Depth_-14_cesm
# Relative_Humidity_-14_cesm
# Specific_Humidity_-14_cesm
# Mixing_Ratio_-14_cesm
# Terrain_Altitude_-14_cesm
# Solar_Radiation_-14_cesm
# geometry_-14_cesm
# DateTime_-14_cesm
# Temperature_C_-14_cesm
# Distance_ptp_-14_cesm
# Cumulative_Dist_-14_cesm
# Dist_from_origin_-14_cesm
# bearings_from_origin_-14_cesm
# bearings_ptp_-14_cesm
# Moisture_Flux_-14_cesm
# Pressure_-13_cesm
# Potential_Temperature_-13_cesm
# Temperature_-13_cesm
# Rainfall_-13_cesm
# Mixing_Depth_-13_cesm
# Relative_Humidity_-13_cesm
# Specific_Humidity_-13_cesm
# Mixing_Ratio_-13_cesm
# Terrain_Altitude_-13_cesm
# Solar_Radiation_-13_cesm
# geometry_-13_cesm
# DateTime_-13_cesm
# Temperature_C_-13_cesm
# Distance_ptp_-13_cesm
# Cumulative_Dist_-13_cesm
# Dist_from_origin_-13_cesm
# bearings_from_origin_-13_cesm
# bearings_ptp_-13_cesm
# Moisture_Flux_-13_cesm
# Pressure_-12_cesm
# Potential_Temperature_-12_cesm
# Temperature_-12_cesm
# Rainfall_-12_cesm
# Mixing_Depth_-12_cesm
# Relative_Humidity_-12_cesm
# Specific_Humidity_-12_cesm
# Mixing_Ratio_-12_cesm
# Terrain_Altitude_-12_cesm
# Solar_Radiation_-12_cesm
# geometry_-12_cesm
# DateTime_-12_cesm
# Temperature_C_-12_cesm
# Distance_ptp_-12_cesm
# Cumulative_Dist_-12_cesm
# Dist_from_origin_-12_cesm
# bearings_from_origin_-12_cesm
# bearings_ptp_-12_cesm
# Moisture_Flux_-12_cesm
# Pressure_-11_cesm
# Potential_Temperature_-11_cesm
# Temperature_-11_cesm
# Rainfall_-11_cesm
# Mixing_Depth_-11_cesm
# Relative_Humidity_-11_cesm
# Specific_Humidity_-11_cesm
# Mixing_Ratio_-11_cesm
# Terrain_Altitude_-11_cesm
# Solar_Radiation_-11_cesm
# geometry_-11_cesm
# DateTime_-11_cesm
# Temperature_C_-11_cesm
# Distance_ptp_-11_cesm
# Cumulative_Dist_-11_cesm
# Dist_from_origin_-11_cesm
# bearings_from_origin_-11_cesm
# bearings_ptp_-11_cesm
# Moisture_Flux_-11_cesm
# Pressure_-10_cesm
# Potential_Temperature_-10_cesm
# Temperature_-10_cesm
# Rainfall_-10_cesm
# Mixing_Depth_-10_cesm
# Relative_Humidity_-10_cesm
# Specific_Humidity_-10_cesm
# Mixing_Ratio_-10_cesm
# Terrain_Altitude_-10_cesm
# Solar_Radiation_-10_cesm
# geometry_-10_cesm
# DateTime_-10_cesm
# Temperature_C_-10_cesm
# Distance_ptp_-10_cesm
# Cumulative_Dist_-10_cesm
# Dist_from_origin_-10_cesm
# bearings_from_origin_-10_cesm
# bearings_ptp_-10_cesm
# Moisture_Flux_-10_cesm
# Pressure_-9_cesm
# Potential_Temperature_-9_cesm
# Temperature_-9_cesm
# Rainfall_-9_cesm
# Mixing_Depth_-9_cesm
# Relative_Humidity_-9_cesm
# Specific_Humidity_-9_cesm
# Mixing_Ratio_-9_cesm
# Terrain_Altitude_-9_cesm
# Solar_Radiation_-9_cesm
# geometry_-9_cesm
# DateTime_-9_cesm
# Temperature_C_-9_cesm
# Distance_ptp_-9_cesm
# Cumulative_Dist_-9_cesm
# Dist_from_origin_-9_cesm
# bearings_from_origin_-9_cesm
# bearings_ptp_-9_cesm
# Moisture_Flux_-9_cesm
# Pressure_-8_cesm
# Potential_Temperature_-8_cesm
# Temperature_-8_cesm
# Rainfall_-8_cesm
# Mixing_Depth_-8_cesm
# Relative_Humidity_-8_cesm
# Specific_Humidity_-8_cesm
# Mixing_Ratio_-8_cesm
# Terrain_Altitude_-8_cesm
# Solar_Radiation_-8_cesm
# geometry_-8_cesm
# DateTime_-8_cesm
# Temperature_C_-8_cesm
# Distance_ptp_-8_cesm
# Cumulative_Dist_-8_cesm
# Dist_from_origin_-8_cesm
# bearings_from_origin_-8_cesm
# bearings_ptp_-8_cesm
# Moisture_Flux_-8_cesm
# Pressure_-7_cesm
# Potential_Temperature_-7_cesm
# Temperature_-7_cesm
# Rainfall_-7_cesm
# Mixing_Depth_-7_cesm
# Relative_Humidity_-7_cesm
# Specific_Humidity_-7_cesm
# Mixing_Ratio_-7_cesm
# Terrain_Altitude_-7_cesm
# Solar_Radiation_-7_cesm
# geometry_-7_cesm
# DateTime_-7_cesm
# Temperature_C_-7_cesm
# Distance_ptp_-7_cesm
# Cumulative_Dist_-7_cesm
# Dist_from_origin_-7_cesm
# bearings_from_origin_-7_cesm
# bearings_ptp_-7_cesm
# Moisture_Flux_-7_cesm
# Pressure_-6_cesm
# Potential_Temperature_-6_cesm
# Temperature_-6_cesm
# Rainfall_-6_cesm
# Mixing_Depth_-6_cesm
# Relative_Humidity_-6_cesm
# Specific_Humidity_-6_cesm
# Mixing_Ratio_-6_cesm
# Terrain_Altitude_-6_cesm
# Solar_Radiation_-6_cesm
# geometry_-6_cesm
# DateTime_-6_cesm
# Temperature_C_-6_cesm
# Distance_ptp_-6_cesm
# Cumulative_Dist_-6_cesm
# Dist_from_origin_-6_cesm
# bearings_from_origin_-6_cesm
# bearings_ptp_-6_cesm
# Moisture_Flux_-6_cesm
# Pressure_-5_cesm
# Potential_Temperature_-5_cesm
# Temperature_-5_cesm
# Rainfall_-5_cesm
# Mixing_Depth_-5_cesm
# Relative_Humidity_-5_cesm
# Specific_Humidity_-5_cesm
# Mixing_Ratio_-5_cesm
# Terrain_Altitude_-5_cesm
# Solar_Radiation_-5_cesm
# geometry_-5_cesm
# DateTime_-5_cesm
# Temperature_C_-5_cesm
# Distance_ptp_-5_cesm
# Cumulative_Dist_-5_cesm
# Dist_from_origin_-5_cesm
# bearings_from_origin_-5_cesm
# bearings_ptp_-5_cesm
# Moisture_Flux_-5_cesm
# Pressure_-4_cesm
# Potential_Temperature_-4_cesm
# Temperature_-4_cesm
# Rainfall_-4_cesm
# Mixing_Depth_-4_cesm
# Relative_Humidity_-4_cesm
# Specific_Humidity_-4_cesm
# Mixing_Ratio_-4_cesm
# Terrain_Altitude_-4_cesm
# Solar_Radiation_-4_cesm
# geometry_-4_cesm
# DateTime_-4_cesm
# Temperature_C_-4_cesm
# Distance_ptp_-4_cesm
# Cumulative_Dist_-4_cesm
# Dist_from_origin_-4_cesm
# bearings_from_origin_-4_cesm
# bearings_ptp_-4_cesm
# Moisture_Flux_-4_cesm
# Pressure_-3_cesm
# Potential_Temperature_-3_cesm
# Temperature_-3_cesm
# Rainfall_-3_cesm
# Mixing_Depth_-3_cesm
# Relative_Humidity_-3_cesm
# Specific_Humidity_-3_cesm
# Mixing_Ratio_-3_cesm
# Terrain_Altitude_-3_cesm
# Solar_Radiation_-3_cesm
# geometry_-3_cesm
# DateTime_-3_cesm
# Temperature_C_-3_cesm
# Distance_ptp_-3_cesm
# Cumulative_Dist_-3_cesm
# Dist_from_origin_-3_cesm
# bearings_from_origin_-3_cesm
# bearings_ptp_-3_cesm
# Moisture_Flux_-3_cesm
# Pressure_-2_cesm
# Potential_Temperature_-2_cesm
# Temperature_-2_cesm
# Rainfall_-2_cesm
# Mixing_Depth_-2_cesm
# Relative_Humidity_-2_cesm
# Specific_Humidity_-2_cesm
# Mixing_Ratio_-2_cesm
# Terrain_Altitude_-2_cesm
# Solar_Radiation_-2_cesm
# geometry_-2_cesm
# DateTime_-2_cesm
# Temperature_C_-2_cesm
# Distance_ptp_-2_cesm
# Cumulative_Dist_-2_cesm
# Dist_from_origin_-2_cesm
# bearings_from_origin_-2_cesm
# bearings_ptp_-2_cesm
# Moisture_Flux_-2_cesm
# Pressure_-1_cesm
# Potential_Temperature_-1_cesm
# Temperature_-1_cesm
# Rainfall_-1_cesm
# Mixing_Depth_-1_cesm
# Relative_Humidity_-1_cesm
# Specific_Humidity_-1_cesm
# Mixing_Ratio_-1_cesm
# Terrain_Altitude_-1_cesm
# Solar_Radiation_-1_cesm
# geometry_-1_cesm
# DateTime_-1_cesm
# Temperature_C_-1_cesm
# Distance_ptp_-1_cesm
# Cumulative_Dist_-1_cesm
# Dist_from_origin_-1_cesm
# bearings_from_origin_-1_cesm
# bearings_ptp_-1_cesm
# Moisture_Flux_-1_cesm
# Pressure_0_cesm
# Potential_Temperature_0_cesm
# Temperature_0_cesm
# Rainfall_0_cesm
# Mixing_Depth_0_cesm
# Relative_Humidity_0_cesm
# Specific_Humidity_0_cesm
# Mixing_Ratio_0_cesm
# Terrain_Altitude_0_cesm
# Solar_Radiation_0_cesm
# geometry_0_cesm
# DateTime_0_cesm
# Temperature_C_0_cesm
# Distance_ptp_0_cesm
# Cumulative_Dist_0_cesm
# Dist_from_origin_0_cesm
# bearings_from_origin_0_cesm
# bearings_ptp_0_cesm
# Moisture_Flux_0_cesm
# Longitude_-24_cesm
# Latitude_-24_cesm
# AltP_meters_-24_cesm
# Longitude_-23_cesm
# Latitude_-23_cesm
# AltP_meters_-23_cesm
# Longitude_-22_cesm
# Latitude_-22_cesm
# AltP_meters_-22_cesm
# Longitude_-21_cesm
# Latitude_-21_cesm
# AltP_meters_-21_cesm
# Longitude_-20_cesm
# Latitude_-20_cesm
# AltP_meters_-20_cesm
# Longitude_-19_cesm
# Latitude_-19_cesm
# AltP_meters_-19_cesm
# Longitude_-18_cesm
# Latitude_-18_cesm
# AltP_meters_-18_cesm
# Longitude_-17_cesm
# Latitude_-17_cesm
# AltP_meters_-17_cesm
# Longitude_-16_cesm
# Latitude_-16_cesm
# AltP_meters_-16_cesm
# Longitude_-15_cesm
# Latitude_-15_cesm
# AltP_meters_-15_cesm
# Longitude_-14_cesm
# Latitude_-14_cesm
# AltP_meters_-14_cesm
# Longitude_-13_cesm
# Latitude_-13_cesm
# AltP_meters_-13_cesm
# Longitude_-12_cesm
# Latitude_-12_cesm
# AltP_meters_-12_cesm
# Longitude_-11_cesm
# Latitude_-11_cesm
# AltP_meters_-11_cesm
# Longitude_-10_cesm
# Latitude_-10_cesm
# AltP_meters_-10_cesm
# Longitude_-9_cesm
# Latitude_-9_cesm
# AltP_meters_-9_cesm
# Longitude_-8_cesm
# Latitude_-8_cesm
# AltP_meters_-8_cesm
# Longitude_-7_cesm
# Latitude_-7_cesm
# AltP_meters_-7_cesm
# Longitude_-6_cesm
# Latitude_-6_cesm
# AltP_meters_-6_cesm
# Longitude_-5_cesm
# Latitude_-5_cesm
# AltP_meters_-5_cesm
# Longitude_-4_cesm
# Latitude_-4_cesm
# AltP_meters_-4_cesm
# Longitude_-3_cesm
# Latitude_-3_cesm
# AltP_meters_-3_cesm
# Longitude_-2_cesm
# Latitude_-2_cesm
# AltP_meters_-2_cesm
# Longitude_-1_cesm
# Latitude_-1_cesm
# AltP_meters_-1_cesm
# Longitude_0_cesm
# Latitude_0_cesm
# AltP_meters_0_cesm
# domain_indicator_cesm
# PAN
# time
# lon
# T_CESM
# U_CESM
# V_CESM
# O3S_CESM
# Z3_CESM
# OMEGA_CESM
# PM25_CESM
# CO_CESM
# E90_CESM
# BR_CESM
# BRCL_CESM
# BRO_CESM
# BROX_CESM
# BROY_CESM
# TBRY_CESM
# BRONO2_CESM
# CCL4_CESM
# CF2CLBR_CESM
# CF3BR_CESM
# CFC11_CESM
# CFC113_CESM
# CFC12_CESM
# CH2O_CESM
# CH3BR_CESM
# CHBR3_CESM
# CH2BR2_CESM
# CH3CCL3_CESM
# CH3CL_CESM
# CH3O2_CESM
# CH3OOH_CESM
# CH4_CESM
# CL_CESM
# CL2_CESM
# CL2O2_CESM
# CLO_CESM
# CLOX_CESM
# CLOY_CESM
# TCLY_CESM
# CLONO2_CESM
# CO2_CESM
# H2_CESM
# H2O_CESM
# H2O2_CESM
# HBR_CESM
# HCFC22_CESM
# HCL_CESM
# HNO3_CESM
# HO2_CESM
# HO2NO2_CESM
# HOBR_CESM
# HOCL_CESM
# N2O_CESM
# N2O5_CESM
# NO_CESM
# NO2_CESM
# NO3_CESM
# NOX_CESM
# NOY_CESM
# O_CESM
# O1D_CESM
# O3_CESM
# OCLO_CESM
# OH_CESM
# C2H4_CESM
# C2H6_CESM
# C2H5O2_CESM
# C2H5OOH_CESM
# CH3CO3_CESM
# CH3COOH_CESM
# CH3CHO_CESM
# CH3OH_CESM
# C2H5OH_CESM
# GLYALD_CESM
# GLYOXAL_CESM
# CH3COOOH_CESM
# EO2_CESM
# EO_CESM
# EOOH_CESM
# PAN_CESM
# C3H6_CESM
# C3H8_CESM
# C3H7O2_CESM
# C3H7OOH_CESM
# CH3COCH3_CESM
# PO2_CESM
# POOH_CESM
# HYAC_CESM
# RO2_CESM
# CH3COCHO_CESM
# ROOH_CESM
# BIGENE_CESM
# BIGALK_CESM
# MEK_CESM
# ENEO2_CESM
# MEKO2_CESM
# MEKOOH_CESM
# MCO3_CESM
# MVK_CESM
# MACR_CESM
# MACRO2_CESM
# MACROOH_CESM
# MPAN_CESM
# ISOP_CESM
# ALKO2_CESM
# ALKOOH_CESM
# BIGALD_CESM
# HYDRALD_CESM
# ISOPNO3_CESM
# XO2_CESM
# XOOH_CESM
# ISOPOOH_CESM
# HCN_CESM
# CH3CN_CESM
# C2H2_CESM
# HCOOH_CESM
# HOCH2OO_CESM
# TOLUENE_CESM
# CRESOL_CESM
# TOLO2_CESM
# TOLOOH_CESM
# BENZENE_CESM
# XYLENES_CESM
# PHENOL_CESM
# BEPOMUC_CESM
# BENZO2_CESM
# PHENO2_CESM
# PHENO_CESM
# PHENOOH_CESM
# C6H5O2_CESM
# C6H5OOH_CESM
# BENZOOH_CESM
# BIGALD1_CESM
# BIGALD2_CESM
# BIGALD3_CESM
# BIGALD4_CESM
# MALO2_CESM
# TEPOMUC_CESM
# BZOO_CESM
# BZOOH_CESM
# BZALD_CESM
# ACBZO2_CESM
# DICARBO2_CESM
# MDIALO2_CESM
# PBZNIT_CESM
# XYLOL_CESM
# XYLOLO2_CESM
# XYLOLOOH_CESM
# XYLENO2_CESM
# XYLENOOH_CESM
# SVOC_CESM
# IVOC_CESM
# MTERP_CESM
# BCARY_CESM
# TERPO2_CESM
# TERPOOH_CESM
# TERPROD1_CESM
# TERP2O2_CESM
# TERPROD2_CESM
# TERP2OOH_CESM
# NTERPO2_CESM
# ISOPAO2_CESM
# ISOPBO2_CESM
# HPALD_CESM
# IEPOX_CESM
# ONITR_CESM
# NOA_CESM
# ALKNIT_CESM
# ISOPNITA_CESM
# ISOPNITB_CESM
# HONITR_CESM
# ISOPNOOH_CESM
# NC4CHO_CESM
# NC4CH2OH_CESM
# TERPNIT_CESM
# NTERPOOH_CESM
# SOAG0_CESM
# SOAG1_CESM
# SOAG2_CESM
# SOAG3_CESM
# SOAG4_CESM
# SO2_CESM
# DMS_CESM
# NH3_CESM
# NH4_CESM
# bc_a1_CESM
# bc_a4_CESM
# dst_a1_CESM
# dst_a2_CESM
# dst_a3_CESM
# ncl_a1_CESM
# ncl_a2_CESM
# ncl_a3_CESM
# pom_a1_CESM
# pom_a4_CESM
# so4_a1_CESM
# so4_a2_CESM
# so4_a3_CESM
# soa1_a1_CESM
# soa2_a1_CESM
# soa3_a1_CESM
# soa4_a1_CESM
# soa5_a1_CESM
# soa1_a2_CESM
# soa2_a2_CESM
# soa3_a2_CESM
# soa4_a2_CESM
# soa5_a2_CESM
# num_a1_CESM
# num_a2_CESM
# num_a4_CESM
# jno3_b_CESM
# jno3_a_CESM
# jn2o5_a_CESM
# jn2o5_b_CESM
# jhno3_CESM
# jho2no2_a_CESM
# jho2no2_b_CESM
# jch2o_a_CESM
# jch2o_b_CESM
# jch3cho_CESM
# jch3ooh_CESM
# jmacr_a_CESM
# jmacr_b_CESM
# jmvk_CESM
# jacet_CESM
# jglyoxal_CESM
# jmgly_CESM
# jcl2_CESM
# jclo_CESM
# jclono2_a_CESM
# jbro_CESM
# jhobr_CESM
# jbrono2_a_CESM
# jbrono2_b_CESM
# jbrcl_CESM
# jmek_CESM
# PMID_CESM
# second_of_day
# date
# lat
# alt
# LAT_df
# LON_df
# ALT_df
# Datetime_df
# Datetime_old
# CH4_df
# CO2_df
# CO_df
# O3_df
# Ethane_df
# DMS_df
# CH3Br_df
# Year
# Month
# Day
# Hour
# domain_indicator_df
# Pressure_-24_df
# Potential_Temperature_-24_df
# Temperature_-24_df
# Rainfall_-24_df
# Mixing_Depth_-24_df
# Relative_Humidity_-24_df
# Specific_Humidity_-24_df
# Mixing_Ratio_-24_df
# Terrain_Altitude_-24_df
# Solar_Radiation_-24_df
# geometry_-24_df
# DateTime_-24_df
# Temperature_C_-24_df
# Distance_ptp_-24_df
# Cumulative_Dist_-24_df
# Dist_from_origin_-24_df
# bearings_from_origin_-24_df
# bearings_ptp_-24_df
# Moisture_Flux_-24_df
# Pressure_-23_df
# Potential_Temperature_-23_df
# Temperature_-23_df
# Rainfall_-23_df
# Mixing_Depth_-23_df
# Relative_Humidity_-23_df
# Specific_Humidity_-23_df
# Mixing_Ratio_-23_df
# Terrain_Altitude_-23_df
# Solar_Radiation_-23_df
# geometry_-23_df
# DateTime_-23_df
# Temperature_C_-23_df
# Distance_ptp_-23_df
# Cumulative_Dist_-23_df
# Dist_from_origin_-23_df
# bearings_from_origin_-23_df
# bearings_ptp_-23_df
# Moisture_Flux_-23_df
# Pressure_-22_df
# Potential_Temperature_-22_df
# Temperature_-22_df
# Rainfall_-22_df
# Mixing_Depth_-22_df
# Relative_Humidity_-22_df
# Specific_Humidity_-22_df
# Mixing_Ratio_-22_df
# Terrain_Altitude_-22_df
# Solar_Radiation_-22_df
# geometry_-22_df
# DateTime_-22_df
# Temperature_C_-22_df
# Distance_ptp_-22_df
# Cumulative_Dist_-22_df
# Dist_from_origin_-22_df
# bearings_from_origin_-22_df
# bearings_ptp_-22_df
# Moisture_Flux_-22_df
# Pressure_-21_df
# Potential_Temperature_-21_df
# Temperature_-21_df
# Rainfall_-21_df
# Mixing_Depth_-21_df
# Relative_Humidity_-21_df
# Specific_Humidity_-21_df
# Mixing_Ratio_-21_df
# Terrain_Altitude_-21_df
# Solar_Radiation_-21_df
# geometry_-21_df
# DateTime_-21_df
# Temperature_C_-21_df
# Distance_ptp_-21_df
# Cumulative_Dist_-21_df
# Dist_from_origin_-21_df
# bearings_from_origin_-21_df
# bearings_ptp_-21_df
# Moisture_Flux_-21_df
# Pressure_-20_df
# Potential_Temperature_-20_df
# Temperature_-20_df
# Rainfall_-20_df
# Mixing_Depth_-20_df
# Relative_Humidity_-20_df
# Specific_Humidity_-20_df
# Mixing_Ratio_-20_df
# Terrain_Altitude_-20_df
# Solar_Radiation_-20_df
# geometry_-20_df
# DateTime_-20_df
# Temperature_C_-20_df
# Distance_ptp_-20_df
# Cumulative_Dist_-20_df
# Dist_from_origin_-20_df
# bearings_from_origin_-20_df
# bearings_ptp_-20_df
# Moisture_Flux_-20_df
# Pressure_-19_df
# Potential_Temperature_-19_df
# Temperature_-19_df
# Rainfall_-19_df
# Mixing_Depth_-19_df
# Relative_Humidity_-19_df
# Specific_Humidity_-19_df
# Mixing_Ratio_-19_df
# Terrain_Altitude_-19_df
# Solar_Radiation_-19_df
# geometry_-19_df
# DateTime_-19_df
# Temperature_C_-19_df
# Distance_ptp_-19_df
# Cumulative_Dist_-19_df
# Dist_from_origin_-19_df
# bearings_from_origin_-19_df
# bearings_ptp_-19_df
# Moisture_Flux_-19_df
# Pressure_-18_df
# Potential_Temperature_-18_df
# Temperature_-18_df
# Rainfall_-18_df
# Mixing_Depth_-18_df
# Relative_Humidity_-18_df
# Specific_Humidity_-18_df
# Mixing_Ratio_-18_df
# Terrain_Altitude_-18_df
# Solar_Radiation_-18_df
# geometry_-18_df
# DateTime_-18_df
# Temperature_C_-18_df
# Distance_ptp_-18_df
# Cumulative_Dist_-18_df
# Dist_from_origin_-18_df
# bearings_from_origin_-18_df
# bearings_ptp_-18_df
# Moisture_Flux_-18_df
# Pressure_-17_df
# Potential_Temperature_-17_df
# Temperature_-17_df
# Rainfall_-17_df
# Mixing_Depth_-17_df
# Relative_Humidity_-17_df
# Specific_Humidity_-17_df
# Mixing_Ratio_-17_df
# Terrain_Altitude_-17_df
# Solar_Radiation_-17_df
# geometry_-17_df
# DateTime_-17_df
# Temperature_C_-17_df
# Distance_ptp_-17_df
# Cumulative_Dist_-17_df
# Dist_from_origin_-17_df
# bearings_from_origin_-17_df
# bearings_ptp_-17_df
# Moisture_Flux_-17_df
# Pressure_-16_df
# Potential_Temperature_-16_df
# Temperature_-16_df
# Rainfall_-16_df
# Mixing_Depth_-16_df
# Relative_Humidity_-16_df
# Specific_Humidity_-16_df
# Mixing_Ratio_-16_df
# Terrain_Altitude_-16_df
# Solar_Radiation_-16_df
# geometry_-16_df
# DateTime_-16_df
# Temperature_C_-16_df
# Distance_ptp_-16_df
# Cumulative_Dist_-16_df
# Dist_from_origin_-16_df
# bearings_from_origin_-16_df
# bearings_ptp_-16_df
# Moisture_Flux_-16_df
# Pressure_-15_df
# Potential_Temperature_-15_df
# Temperature_-15_df
# Rainfall_-15_df
# Mixing_Depth_-15_df
# Relative_Humidity_-15_df
# Specific_Humidity_-15_df
# Mixing_Ratio_-15_df
# Terrain_Altitude_-15_df
# Solar_Radiation_-15_df
# geometry_-15_df
# DateTime_-15_df
# Temperature_C_-15_df
# Distance_ptp_-15_df
# Cumulative_Dist_-15_df
# Dist_from_origin_-15_df
# bearings_from_origin_-15_df
# bearings_ptp_-15_df
# Moisture_Flux_-15_df
# Pressure_-14_df
# Potential_Temperature_-14_df
# Temperature_-14_df
# Rainfall_-14_df
# Mixing_Depth_-14_df
# Relative_Humidity_-14_df
# Specific_Humidity_-14_df
# Mixing_Ratio_-14_df
# Terrain_Altitude_-14_df
# Solar_Radiation_-14_df
# geometry_-14_df
# DateTime_-14_df
# Temperature_C_-14_df
# Distance_ptp_-14_df
# Cumulative_Dist_-14_df
# Dist_from_origin_-14_df
# bearings_from_origin_-14_df
# bearings_ptp_-14_df
# Moisture_Flux_-14_df
# Pressure_-13_df
# Potential_Temperature_-13_df
# Temperature_-13_df
# Rainfall_-13_df
# Mixing_Depth_-13_df
# Relative_Humidity_-13_df
# Specific_Humidity_-13_df
# Mixing_Ratio_-13_df
# Terrain_Altitude_-13_df
# Solar_Radiation_-13_df
# geometry_-13_df
# DateTime_-13_df
# Temperature_C_-13_df
# Distance_ptp_-13_df
# Cumulative_Dist_-13_df
# Dist_from_origin_-13_df
# bearings_from_origin_-13_df
# bearings_ptp_-13_df
# Moisture_Flux_-13_df
# Pressure_-12_df
# Potential_Temperature_-12_df
# Temperature_-12_df
# Rainfall_-12_df
# Mixing_Depth_-12_df
# Relative_Humidity_-12_df
# Specific_Humidity_-12_df
# Mixing_Ratio_-12_df
# Terrain_Altitude_-12_df
# Solar_Radiation_-12_df
# geometry_-12_df
# DateTime_-12_df
# Temperature_C_-12_df
# Distance_ptp_-12_df
# Cumulative_Dist_-12_df
# Dist_from_origin_-12_df
# bearings_from_origin_-12_df
# bearings_ptp_-12_df
# Moisture_Flux_-12_df
# Pressure_-11_df
# Potential_Temperature_-11_df
# Temperature_-11_df
# Rainfall_-11_df
# Mixing_Depth_-11_df
# Relative_Humidity_-11_df
# Specific_Humidity_-11_df
# Mixing_Ratio_-11_df
# Terrain_Altitude_-11_df
# Solar_Radiation_-11_df
# geometry_-11_df
# DateTime_-11_df
# Temperature_C_-11_df
# Distance_ptp_-11_df
# Cumulative_Dist_-11_df
# Dist_from_origin_-11_df
# bearings_from_origin_-11_df
# bearings_ptp_-11_df
# Moisture_Flux_-11_df
# Pressure_-10_df
# Potential_Temperature_-10_df
# Temperature_-10_df
# Rainfall_-10_df
# Mixing_Depth_-10_df
# Relative_Humidity_-10_df
# Specific_Humidity_-10_df
# Mixing_Ratio_-10_df
# Terrain_Altitude_-10_df
# Solar_Radiation_-10_df
# geometry_-10_df
# DateTime_-10_df
# Temperature_C_-10_df
# Distance_ptp_-10_df
# Cumulative_Dist_-10_df
# Dist_from_origin_-10_df
# bearings_from_origin_-10_df
# bearings_ptp_-10_df
# Moisture_Flux_-10_df
# Pressure_-9_df
# Potential_Temperature_-9_df
# Temperature_-9_df
# Rainfall_-9_df
# Mixing_Depth_-9_df
# Relative_Humidity_-9_df
# Specific_Humidity_-9_df
# Mixing_Ratio_-9_df
# Terrain_Altitude_-9_df
# Solar_Radiation_-9_df
# geometry_-9_df
# DateTime_-9_df
# Temperature_C_-9_df
# Distance_ptp_-9_df
# Cumulative_Dist_-9_df
# Dist_from_origin_-9_df
# bearings_from_origin_-9_df
# bearings_ptp_-9_df
# Moisture_Flux_-9_df
# Pressure_-8_df
# Potential_Temperature_-8_df
# Temperature_-8_df
# Rainfall_-8_df
# Mixing_Depth_-8_df
# Relative_Humidity_-8_df
# Specific_Humidity_-8_df
# Mixing_Ratio_-8_df
# Terrain_Altitude_-8_df
# Solar_Radiation_-8_df
# geometry_-8_df
# DateTime_-8_df
# Temperature_C_-8_df
# Distance_ptp_-8_df
# Cumulative_Dist_-8_df
# Dist_from_origin_-8_df
# bearings_from_origin_-8_df
# bearings_ptp_-8_df
# Moisture_Flux_-8_df
# Pressure_-7_df
# Potential_Temperature_-7_df
# Temperature_-7_df
# Rainfall_-7_df
# Mixing_Depth_-7_df
# Relative_Humidity_-7_df
# Specific_Humidity_-7_df
# Mixing_Ratio_-7_df
# Terrain_Altitude_-7_df
# Solar_Radiation_-7_df
# geometry_-7_df
# DateTime_-7_df
# Temperature_C_-7_df
# Distance_ptp_-7_df
# Cumulative_Dist_-7_df
# Dist_from_origin_-7_df
# bearings_from_origin_-7_df
# bearings_ptp_-7_df
# Moisture_Flux_-7_df
# Pressure_-6_df
# Potential_Temperature_-6_df
# Temperature_-6_df
# Rainfall_-6_df
# Mixing_Depth_-6_df
# Relative_Humidity_-6_df
# Specific_Humidity_-6_df
# Mixing_Ratio_-6_df
# Terrain_Altitude_-6_df
# Solar_Radiation_-6_df
# geometry_-6_df
# DateTime_-6_df
# Temperature_C_-6_df
# Distance_ptp_-6_df
# Cumulative_Dist_-6_df
# Dist_from_origin_-6_df
# bearings_from_origin_-6_df
# bearings_ptp_-6_df
# Moisture_Flux_-6_df
# Pressure_-5_df
# Potential_Temperature_-5_df
# Temperature_-5_df
# Rainfall_-5_df
# Mixing_Depth_-5_df
# Relative_Humidity_-5_df
# Specific_Humidity_-5_df
# Mixing_Ratio_-5_df
# Terrain_Altitude_-5_df
# Solar_Radiation_-5_df
# geometry_-5_df
# DateTime_-5_df
# Temperature_C_-5_df
# Distance_ptp_-5_df
# Cumulative_Dist_-5_df
# Dist_from_origin_-5_df
# bearings_from_origin_-5_df
# bearings_ptp_-5_df
# Moisture_Flux_-5_df
# Pressure_-4_df
# Potential_Temperature_-4_df
# Temperature_-4_df
# Rainfall_-4_df
# Mixing_Depth_-4_df
# Relative_Humidity_-4_df
# Specific_Humidity_-4_df
# Mixing_Ratio_-4_df
# Terrain_Altitude_-4_df
# Solar_Radiation_-4_df
# geometry_-4_df
# DateTime_-4_df
# Temperature_C_-4_df
# Distance_ptp_-4_df
# Cumulative_Dist_-4_df
# Dist_from_origin_-4_df
# bearings_from_origin_-4_df
# bearings_ptp_-4_df
# Moisture_Flux_-4_df
# Pressure_-3_df
# Potential_Temperature_-3_df
# Temperature_-3_df
# Rainfall_-3_df
# Mixing_Depth_-3_df
# Relative_Humidity_-3_df
# Specific_Humidity_-3_df
# Mixing_Ratio_-3_df
# Terrain_Altitude_-3_df
# Solar_Radiation_-3_df
# geometry_-3_df
# DateTime_-3_df
# Temperature_C_-3_df
# Distance_ptp_-3_df
# Cumulative_Dist_-3_df
# Dist_from_origin_-3_df
# bearings_from_origin_-3_df
# bearings_ptp_-3_df
# Moisture_Flux_-3_df
# Pressure_-2_df
# Potential_Temperature_-2_df
# Temperature_-2_df
# Rainfall_-2_df
# Mixing_Depth_-2_df
# Relative_Humidity_-2_df
# Specific_Humidity_-2_df
# Mixing_Ratio_-2_df
# Terrain_Altitude_-2_df
# Solar_Radiation_-2_df
# geometry_-2_df
# DateTime_-2_df
# Temperature_C_-2_df
# Distance_ptp_-2_df
# Cumulative_Dist_-2_df
# Dist_from_origin_-2_df
# bearings_from_origin_-2_df
# bearings_ptp_-2_df
# Moisture_Flux_-2_df
# Pressure_-1_df
# Potential_Temperature_-1_df
# Temperature_-1_df
# Rainfall_-1_df
# Mixing_Depth_-1_df
# Relative_Humidity_-1_df
# Specific_Humidity_-1_df
# Mixing_Ratio_-1_df
# Terrain_Altitude_-1_df
# Solar_Radiation_-1_df
# geometry_-1_df
# DateTime_-1_df
# Temperature_C_-1_df
# Distance_ptp_-1_df
# Cumulative_Dist_-1_df
# Dist_from_origin_-1_df
# bearings_from_origin_-1_df
# bearings_ptp_-1_df
# Moisture_Flux_-1_df
# Pressure_0_df
# Potential_Temperature_0_df
# Temperature_0_df
# Rainfall_0_df
# Mixing_Depth_0_df
# Relative_Humidity_0_df
# Specific_Humidity_0_df
# Mixing_Ratio_0_df
# Terrain_Altitude_0_df
# Solar_Radiation_0_df
# geometry_0_df
# DateTime_0_df
# Temperature_C_0_df
# Distance_ptp_0_df
# Cumulative_Dist_0_df
# Dist_from_origin_0_df
# bearings_from_origin_0_df
# bearings_ptp_0_df
# Moisture_Flux_0_df
# Longitude_-24_df
# Latitude_-24_df
# AltP_meters_-24_df
# Longitude_-23_df
# Latitude_-23_df
# AltP_meters_-23_df
# Longitude_-22_df
# Latitude_-22_df
# AltP_meters_-22_df
# Longitude_-21_df
# Latitude_-21_df
# AltP_meters_-21_df
# Longitude_-20_df
# Latitude_-20_df
# AltP_meters_-20_df
# Longitude_-19_df
# Latitude_-19_df
# AltP_meters_-19_df
# Longitude_-18_df
# Latitude_-18_df
# AltP_meters_-18_df
# Longitude_-17_df
# Latitude_-17_df
# AltP_meters_-17_df
# Longitude_-16_df
# Latitude_-16_df
# AltP_meters_-16_df
# Longitude_-15_df
# Latitude_-15_df
# AltP_meters_-15_df
# Longitude_-14_df
# Latitude_-14_df
# AltP_meters_-14_df
# Longitude_-13_df
# Latitude_-13_df
# AltP_meters_-13_df
# Longitude_-12_df
# Latitude_-12_df
# AltP_meters_-12_df
# Longitude_-11_df
# Latitude_-11_df
# AltP_meters_-11_df
# Longitude_-10_df
# Latitude_-10_df
# AltP_meters_-10_df
# Longitude_-9_df
# Latitude_-9_df
# AltP_meters_-9_df
# Longitude_-8_df
# Latitude_-8_df
# AltP_meters_-8_df
# Longitude_-7_df
# Latitude_-7_df
# AltP_meters_-7_df
# Longitude_-6_df
# Latitude_-6_df
# AltP_meters_-6_df
# Longitude_-5_df
# Latitude_-5_df
# AltP_meters_-5_df
# Longitude_-4_df
# Latitude_-4_df
# AltP_meters_-4_df
# Longitude_-3_df
# Latitude_-3_df
# AltP_meters_-3_df
# Longitude_-2_df
# Latitude_-2_df
# AltP_meters_-2_df
# Longitude_-1_df
# Latitude_-1_df
# AltP_meters_-1_df
# Longitude_0_df
# Latitude_0_df
# AltP_meters_0_df
# lat_lon_interaction_0
# lat_diff
# lon_diff
# straight_line_efficiency_ratio
# dew_point_-24
# dew_point_-23
# dew_point_-22
# dew_point_-21
# dew_point_-20
# dew_point_-19
# dew_point_-18
# dew_point_-17
# dew_point_-16
# dew_point_-15
# dew_point_-14
# dew_point_-13
# dew_point_-12
# dew_point_-11
# dew_point_-10
# dew_point_-9
# dew_point_-8
# dew_point_-7
# dew_point_-6
# dew_point_-5
# dew_point_-4
# dew_point_-3
# dew_point_-2
# dew_point_-1
# dew_point_0
# LCL_-24
# LCL_-23
# LCL_-22
# LCL_-21
# LCL_-20
# LCL_-19
# LCL_-18
# LCL_-17
# LCL_-16
# LCL_-15
# LCL_-14
# LCL_-13
# LCL_-12
# LCL_-11
# LCL_-10
# LCL_-9
# LCL_-8
# LCL_-7
# LCL_-6
# LCL_-5
# LCL_-4
# LCL_-3
# LCL_-2
# LCL_-1
# LCL_0
# Rainfall_Estimate_-24
# Rainfall_Estimate_-23
# Rainfall_Estimate_-22
# Rainfall_Estimate_-21
# Rainfall_Estimate_-20
# Rainfall_Estimate_-19
# Rainfall_Estimate_-18
# Rainfall_Estimate_-17
# Rainfall_Estimate_-16
# Rainfall_Estimate_-15
# Rainfall_Estimate_-14
# Rainfall_Estimate_-13
# Rainfall_Estimate_-12
# Rainfall_Estimate_-11
# Rainfall_Estimate_-10
# Rainfall_Estimate_-9
# Rainfall_Estimate_-8
# Rainfall_Estimate_-7
# Rainfall_Estimate_-6
# Rainfall_Estimate_-5
# Rainfall_Estimate_-4
# Rainfall_Estimate_-3
# Rainfall_Estimate_-2
# Rainfall_Estimate_-1
# Rainfall_Estimate_0
# time_difference_-24
# time_difference_seconds_-24
# hour_sin_-24
# hour_cos_-24
# month_sin_-24
# month_cos_-24
# time_difference_-23
# time_difference_seconds_-23
# hour_sin_-23
# hour_cos_-23
# month_sin_-23
# month_cos_-23
# time_difference_-22
# time_difference_seconds_-22
# hour_sin_-22
# hour_cos_-22
# month_sin_-22
# month_cos_-22
# time_difference_-21
# time_difference_seconds_-21
# hour_sin_-21
# hour_cos_-21
# month_sin_-21
# month_cos_-21
# time_difference_-20
# time_difference_seconds_-20
# hour_sin_-20
# hour_cos_-20
# month_sin_-20
# month_cos_-20
# time_difference_-19
# time_difference_seconds_-19
# hour_sin_-19
# hour_cos_-19
# month_sin_-19
# month_cos_-19
# time_difference_-18
# time_difference_seconds_-18
# hour_sin_-18
# hour_cos_-18
# month_sin_-18
# month_cos_-18
# time_difference_-17
# time_difference_seconds_-17
# hour_sin_-17
# hour_cos_-17
# month_sin_-17
# month_cos_-17
# time_difference_-16
# time_difference_seconds_-16
# hour_sin_-16
# hour_cos_-16
# month_sin_-16
# month_cos_-16
# time_difference_-15
# time_difference_seconds_-15
# hour_sin_-15
# hour_cos_-15
# month_sin_-15
# month_cos_-15
# time_difference_-14
# time_difference_seconds_-14
# hour_sin_-14
# hour_cos_-14
# month_sin_-14
# month_cos_-14
# time_difference_-13
# time_difference_seconds_-13
# hour_sin_-13
# hour_cos_-13
# month_sin_-13
# month_cos_-13
# time_difference_-12
# time_difference_seconds_-12
# hour_sin_-12
# hour_cos_-12
# month_sin_-12
# month_cos_-12
# time_difference_-11
# time_difference_seconds_-11
# hour_sin_-11
# hour_cos_-11
# month_sin_-11
# month_cos_-11
# time_difference_-10
# time_difference_seconds_-10
# hour_sin_-10
# hour_cos_-10
# month_sin_-10
# month_cos_-10
# time_difference_-9
# time_difference_seconds_-9
# hour_sin_-9
# hour_cos_-9
# month_sin_-9
# month_cos_-9
# time_difference_-8
# time_difference_seconds_-8
# hour_sin_-8
# hour_cos_-8
# month_sin_-8
# month_cos_-8
# time_difference_-7
# time_difference_seconds_-7
# hour_sin_-7
# hour_cos_-7
# month_sin_-7
# month_cos_-7
# time_difference_-6
# time_difference_seconds_-6
# hour_sin_-6
# hour_cos_-6
# month_sin_-6
# month_cos_-6
# time_difference_-5
# time_difference_seconds_-5
# hour_sin_-5
# hour_cos_-5
# month_sin_-5
# month_cos_-5
# time_difference_-4
# time_difference_seconds_-4
# hour_sin_-4
# hour_cos_-4
# month_sin_-4
# month_cos_-4
# time_difference_-3
# time_difference_seconds_-3
# hour_sin_-3
# hour_cos_-3
# month_sin_-3
# month_cos_-3
# time_difference_-2
# time_difference_seconds_-2
# hour_sin_-2
# hour_cos_-2
# month_sin_-2
# month_cos_-2
# time_difference_-1
# time_difference_seconds_-1
# hour_sin_-1
# hour_cos_-1
# month_sin_-1
# month_cos_-1
# time_difference_0
# time_difference_seconds_0
# hour_sin_0
# hour_cos_0
# month_sin_0
# month_cos_0
# std_pressure
# delta_pressure
# mean_pressure
# sum_pressure
# std_potential_temperature
# delta_potential_temperature
# mean_potential_temperature
# sum_potential_temperature
# std_relative_humidity
# delta_relative_humidity
# mean_relative_humidity
# sum_relative_humidity
# std_specific_humidity
# delta_specific_humidity
# mean_specific_humidity
# sum_specific_humidity
# std_solar_radiation
# delta_solar_radiation
# mean_solar_radiation
# sum_solar_radiation
# std_mixing_depth
# delta_mixing_depth
# mean_mixing_depth
# sum_mixing_depth
# std_moisture_flux
# delta_moisture_flux
# mean_moisture_flux
# sum_moisture_flux
# std_temperature_c
# delta_temperature_c
# mean_temperature_c
# sum_temperature_c
# std_rainfall_estimate
# delta_rainfall_estimate
# mean_rainfall_estimate
# sum_rainfall_estimate
# std_lcl
# delta_lcl
# mean_lcl
# sum_lcl
# std_dew_point
# delta_dew_point
# mean_dew_point
# sum_dew_point
# std_latitude
# delta_latitude
# mean_latitude
# sum_latitude
# std_longitude
# delta_longitude
# mean_longitude
# sum_longitude
# Velocity_-24
# Velocity_-23
# Velocity_-22
# Velocity_-21
# Velocity_-20
# Velocity_-19
# Velocity_-18
# Velocity_-17
# Velocity_-16
# Velocity_-15
# Velocity_-14
# Velocity_-13
# Velocity_-12
# Velocity_-11
# Velocity_-10
# Velocity_-9
# Velocity_-8
# Velocity_-7
# Velocity_-6
# Velocity_-5
# Velocity_-4
# Velocity_-3
# Velocity_-2
# Velocity_-1
# std_velocity
# delta_velocity
# mean_velocity
# domain_label
# spatial_cluster
# kfold_Longitude
# kfold_cluster
# min_distance_to_cluster_centroids
# mean_distance_to_cluster_centroids
# min_distance_to_t1000_cities
# mean_distance_to_t1000_cities
# min_distance_to_extent_corners
# mean_distance_to_extent_corners
# min_distance_to_antimeridian
# mean_distance_to_antimeridian
# PASTEL_CO
# PASTEL_CH4
# PASTEL_Ethane
# PASTEL_DMS
# PASTEL_CH3Br
# PASTEL_O3

# %%
atom_cesm_f["O3_df"]
# Out:
# 0       48.920000
# 1       74.342857
# 2       71.885714
# 3       99.014286
# 4       95.383333
#           ...
# 4604    52.540000
# 4605          NaN
# 4606          NaN
# 4607          NaN
# 4608          NaN
# Name: O3_df, Length: 4609, dtype: float64

# %%
atom_cesm_f["CH4_CESM"] = atom_cesm_f["CH4_CESM"] * 1e9
atom_cesm_f["O3_CESM"] = atom_cesm_f["O3_CESM"] * 1e9
atom_cesm_f["CO_CESM"] = atom_cesm_f["CO_CESM"] * 1e9
atom_cesm_f["CH3BR_CESM"] = atom_cesm_f["CH3BR_CESM"] * 1e12
atom_cesm_f["C2H6_CESM"] = atom_cesm_f["C2H6_CESM"] * 1e12
atom_cesm_f["DMS_CESM"] = atom_cesm_f["DMS_CESM"] * 1e12

# %%
ATS_names = ["CO", "CH4", "CH3Br", "DMS", "O3", "Ethane"]

# Create a mapping of names to specific column names for the GMI and PASTEL models
model_mapping = {
    "CO": ("CO_df", "CO_CESM", "PASTEL_CO"),
    "CH3Br": ("CH3Br_df", "CH3BR_CESM", "PASTEL_CH3Br"),
    "CH4": ("CH4_df", "CH4_CESM", "PASTEL_CH4"),
    "Ethane": ("Ethane_df", "C2H6_CESM", "PASTEL_Ethane"),
    "O3": ("O3_df", "O3_CESM", "PASTEL_O3"),
    "DMS" : ("DMS_df", "DMS_CESM", "PASTEL_DMS"),
}

# Initialize an empty list to store results
metrics_list = []

# Loop through species and calculate metrics
for species, (data_col, cesm_col, pastel_col) in model_mapping.items():
    # Drop NaN values from both data and target columns
    merged_cesm = pd.concat([atom_cesm_f[data_col], atom_cesm_f[cesm_col]], axis=1).dropna()

    if species == 'DMS':
        merged_cesm = merged_cesm[merged_cesm[cesm_col] >= 1]

    merged_pastel = pd.concat([atom_cesm_f[data_col], atom_cesm_f[pastel_col]], axis=1).dropna()
    
    # Ensure the same rows are kept in both DataFrames (i.e., intersection of indexes)
    merged_cesm = merged_cesm.loc[merged_cesm.index.intersection(merged_pastel.index)]
    
    # print(len(merged_cesm))

    # scatter_plot(merged_cesm[data_col], merged_cesm[cesm_col], "cesm_scatter", species)
    # scatter_plot(merged_pastel[data_col], merged_pastel[pastel_col], "pastel_sctter", species)

    # Calculate metrics for GMI and PASTEL after dropping NaN
    metrics_list.append(
        calculate_and_organize_metrics_model(merged_cesm[data_col], merged_cesm[cesm_col], "CESM", species)
    )
    metrics_list.append(
        calculate_and_organize_metrics_model(merged_pastel[data_col], merged_pastel[pastel_col], "PASTEL", species)
    )

# Combine all metrics into a single DataFrame
model_metrics = pd.concat(metrics_list, ignore_index=True)

model_metrics[['Model', 'ATS', 'RMSE', 'MAE', "R2"]]
# Out:
#      Model     ATS        RMSE         MAE        R2
# 0     CESM      CO   28.355410   21.444255  0.158853
# 1   PASTEL      CO   11.530789    7.110605  0.860903
# 2     CESM   CH3Br    0.802643    0.637930 -0.760859
# 3   PASTEL   CH3Br    0.387029    0.269500  0.590582
# 4     CESM     CH4   20.901074   15.719690  0.840360
# 5   PASTEL     CH4   13.855175    8.643548  0.929850
# 6     CESM  Ethane  639.833650  381.726601 -0.096939
# 7   PASTEL  Ethane  230.985029  109.462410  0.857040
# 8     CESM      O3   39.830331   21.373700  0.801159
# 9   PASTEL      O3   28.361160   11.933836  0.899185
# 10    CESM     DMS   83.658247   41.903542 -9.174775
# 11  PASTEL     DMS   14.598982    7.209844  0.616503

# %%
for c in seac4rs_f.columns:
    print(c)
# Out:
# iindex
# Fractional_Day
# STARTTIME
# STOPTIME
# UTC
# JDAY
# INDEX
# FLIGHT
# LOCAL_SUN_TIME
# LAT_seac4rs
# LON_seac4rs
# ALT_seac4rs
# PRESSURE_obs
# TEMPERATURE
# THETA
# O3COLUMN
# SZA
# WNS
# WND
# GPS_ALT
# RadarAlt
# GRD_SPD
# TAS
# IAS
# MachNumber
# VerticalSpeed
# HDG
# TRK
# DriftAngle
# PITCH
# ROLL
# StaticTemp_Experimenter
# PotentialTemp
# Dewpoint
# TotalTemp
# TotalTemp_Experimenter
# IR_SurfTemp
# CabinPressure
# SolarZenithAngle
# AircraftSunElevation
# SunAzimuth
# AircraftSunAzimuth
# H2O_MixingRatio
# H2O_VaporPres
# H2O_SatVaporPresWater
# H2O_SatVaporPresIce
# H2O_RelativeHumidity
# StaticPressure_MMS
# StaticTemp_MMS
# TAS_MMS
# U
# V
# W
# TEDR
# REYN
# GPS_LAT_MMS
# GPS_LON_MMS
# GPS_ALT_MMS
# THETA_MMS
# ROLL_MMS
# HDG_MMS
# PITCH_MMS
# U_AIMMS20
# V_AIMMS20
# W_AIMMS20
# CO2_seac4rs
# CO_DACOM
# CO-SourceFlag_DACOM
# H2O_DLH
# CH2O_CAMS
# CH2O_LIF
# NO2_ESRL
# NOy_ESRL
# NO_ESRL
# O3_obs
# NO2_TDLIF
# MPN_TDLIF
# PNs_TDLIF
# ANs_TDLIF
# HNO3_NO3-lt1um_SAGA
# Sulfate-lt1um_SAGA
# Cl_SAGA-AERO
# Br_SAGA-AERO
# NO3_SAGA-AERO
# SO4_SAGA-AERO
# C2O4_SAGA-AERO
# Na_SAGA-AERO
# NH4_SAGA-AERO
# K_SAGA-AERO
# Mg_SAGA-AERO
# Ca_SAGA-AERO
# PAN_obs
# PPN_GTCIMS
# APAN_GTCIMS
# PiBN_GTCIMS
# SO2_GTCIMS
# HCl_GTCIMS
# HNO4_GTCIMS
# J[O3->O2+O(1D)]
# J[NO2->NO+O(3P)]
# J[H2O2->2OH]
# J[N2O5->NO3+NO2]
# J[HNO2->OH+NO]
# J[HNO3->OH+NO2]
# J[HNO4->HO2+NO2]
# J[CH2O->H+HCO]
# J[CH2O->H2+CO]
# J[CH3CHO->CH3+HCO]
# J[C2H5CHO->C2H5+HCO]
# J[CH3OOH->CH3O+OH]
# J[CH3ONO2->CH3O+NO2]
# J[CH3CH2ONO2->CH3CH2O+NO2]
# J[CH3CO(OONO2)[PAN]->CH3CO(OO)+NO2]
# J[CH3CO(OONO2)[PAN]->CH3CO(O)+NO3]
# J[MAC->Products]
# J[MVK->Products]
# J[CH3COCH3->CH3CO+CH3]
# J[CH3COCH2CH3->CH3CO+CH2CH3]
# J[CHOCHO->HCO+HCO]
# J[CHOCHO->H2+2CO]
# J[CHOCHO->CH2O+CO]
# J[CH3COCHO->CH3CO+HCO]
# J[Cl2->Cl+Cl]
# J[ClO->Cl+O(3P)]
# J[ClNO2->Cl+NO2]
# J[ClONO->Cl+NO2]
# J[ClONO2->Cl+NO3]
# J[ClONO2->ClO+NO2]
# J[Br2->Br+Br]
# J[BrO->Br+O]
# J[HOBr->OH+Br]
# J[BrNO->Br+NO]
# J[BrONO->Br+NO2]
# J[BrONO->BrO+NO]
# J[BrNO2->Br+NO2]
# J[BrONO2->BrO+NO2]
# J[BrONO2->Br+NO3]
# J[BrCl->Br+Cl]
# J[CHBr3->Products]
# J[CH3CH2CH2CHO->C3H7+HCO]
# J[CH3CH2CH2CHO->C2H4+CH2CHOH]
# J[Br2O->Products]
# Org-lt-1um_AMS
# Sulfate-lt-1um_AMS
# Nitrate-lt-1um_AMS
# Ammonium-lt-1um_AMS
# Chloride-lt-1um_AMS
# stdPT-to-AMB_Conversion_AMS
# PM1-Inlet-Corr_AMS
# IceFlag_AMS
# OtoC-ratio-lt-1um_AMS
# HtoC-ratio-lt-1um_AMS
# OAtoOC-ratio-lt-1um_AMS
# f43-lt-1um_AMS
# f44-lt-1um_AMS
# f57-lt-1um_AMS
# f60-lt-1um_AMS
# AmmBalance-lt-1um_AMS
# OrgNitr-AerosolNitr-ratio-lt-1um_AMS
# WSOC
# WS-Abs365nm
# MS-Abs365nm
# BC_mass_90to550nm_HDSP2
# CNgt3nm
# CNgt10nm
# CNgt10nm_nonvol
# NumConc-STP_CCN
# NumConc-amb_CCN
# Supersaturation_CCN
# IntegN_Daero-PSL_APS_LARGE
# IntegS_Daero-PSL_APS_LARGE
# IntegV_Daero-PSL_APS_LARGE
# IntegN_Dopt-PSL_LAS_LARGE
# IntegS_Dopt-PSL_LAS_LARGE
# IntegV_Dopt-PSL_LAS_LARGE
# IntegN_Dmob-PSL_SMPS_LARGE
# IntegS_Dmob-PSL_SMPS_LARGE
# IntegV_Dmob-PSL_SMPS_LARGE
# IntegN_Dopt-AmmSO4_UHSAS_LARGE
# IntegS_Dopt-AmmSO4_UHSAS_LARGE
# IntegV_Dopt-AmmSO4_UHSAS_LARGE
# IntegN_Dopt-PSL_UHSAS_LARGE
# IntegS_Dopt-PSL_UHSAS_LARGE
# IntegV_Dopt-PSL_UHSAS_LARGE
# stdPT-to-AMB_Conversion_NOAA
# Meas-RH_NOAA
# Asym-Param_70to1000nm_NOAA
# IntegN_Dopt70to1000nm-AmmSO4_NOAA
# IntegS_Dopt70to1000nm-AmmSO4_NOAA
# IntegV_Dopt70to1000nm-AmmSO4_NOAA
# SCAT550nm-amb_total_LARGE
# SCAT450nm-dry_total_LARGE
# SCAT550nm-dry_total_LARGE
# SCAT700nm-dry_total_LARGE
# SCAT450nm-dry_lt1um_LARGE
# SCAT550nm-dry_lt1um_LARGE
# SCAT700nm-dry_lt1um_LARGE
# ABS470nm-dry_total_LARGE
# ABS532nm-dry_total_LARGE
# ABS660nm-dry_total_LARGE
# EXT532nm-amb_total_LARGE
# EXT532nm-dry_total_LARGE
# gamma-550nm_LARGE
# fRH-550nm_RH20to80_LARGE
# AE_SCAT_450to550nm_LARGE
# AE_ABS_450to550nm_LARGE
# SSA450nm-dry_TSIandPSAP_LARGE
# SSA550nm-dry_TSIandPSAP_LARGE
# SSA700nm-dry_TSIandPSAP_LARGE
# SSA550nm-amb_TSIandPSAP_LARGE
# stdPT-to-AMB_Conversion_LARGE
# InletFlag_LARGE
# ABS405nm-dry_PAS_NOAA-AeroAbs
# ABS532nm-dry_PAS_NOAA-AeroAbs
# ABS660nm-dry_PAS_NOAA-AeroAbs
# ABS405nm-TD_PAS_NOAA-AeroAbs
# ABS660nm-TD_PAS_NOAA-AeroAbs
# stdPT-to-AMB_Conversion_NOAA-AeroAbs
# EXT405nm-dry_NOAA-AeroExt
# EXT532nm-dry_NOAA-AeroExt
# EXT662nm-dry_NOAA-AeroExt
# EXT532nm-medRH_NOAA-AeroExt
# EXT532nm-highRH_NOAA-AeroExt
# EXT405nm-TD_NOAA-AeroExt
# EXT662nm-TD_NOAA-AeroExt
# RHdry_NOAA-AeroExt
# RHmed_NOAA-AeroExt
# RHhigh_NOAA-AeroExt
# stdPT-to-AMB_Conversion_NOAA-AeroExt
# AE_EXT_405to532nm_AOP
# AE_EXT_405to662nm_AOP
# fRH-532nm_RH20to70_AOP
# fRH-532nm_RH20to90_AOP
# gamma-532nm_RH20to90_AOP
# EXT532nm-amb_AOP
# Scat473nm_PINEPH
# Scat532nm_PINEPH
# Scat671nm_PINEPH
# Asym473nm_PINEPH
# Asym532nm_PINEPH
# Asym671nm_PINEPH
# RI-Real_671nm_PINEPH
# RI-Real_532nm_PINEPH
# RI-Real_671nm_PINEPH.1
# RI-Imag_671nm_PINEPH
# RI-Imag_532nm_PINEPH
# RI-Imag_473nm_PINEPH
# SSA_671nm_PINEPH
# SSA_532nm_PINEPH
# SSA_473nm_PINEPH
# Sphericity_PINEPH
# Dp_DASH
# RH_DASH
# GrowthFactor_DASH
# SampleVolume_2DS
# ParticleConc_2DS
# ParticleExt_2DS
# IWC_2DS
# IrregularCount_2DS
# MeanDiameter_2DS
# MedianVolDiameter_2DS
# EffectiveDiameter_2DS
# TotalCount_2DS
# ParticleConc_FCDP
# ParticleExt_FCDP
# LWC_FCDP
# SampleVolume_FCDP
# EventCount
# SampleVolume_HVPS
# ParticleConc_HVPS
# ParticleExt_HVPS
# IWC_HVPS
# IrregularCount_HVPS
# MeanDiameter_HVPS
# MedianVolDiameter_HVPS
# EffectiveDiameter_HVPS
# TotalCount_HVPS
# PHASE_GOES13
# IcingIndex_GOES13
# CloudOpticalDepth-MEAN_GOES13
# R-eff-MEAN_GOES13
# D-eff-MEAN_GOES13
# LWP-MEAN_GOES13
# IWP-MEAN_GOES13
# IR-emit-MEAN_GOES13
# T-eff-MEAN_GOES13
# Z-top-MEAN_GOES13
# Z-eff-MEAN_GOES13
# Z-bot-MEAN_GOES13
# Z-thk-MEAN_GOES13
# P-top-MEAN_GOES13
# P-eff-MEAN_GOES13
# P-bot-MEAN_GOES13
# BroadbandAlbedo-MEAN_GOES13
# BroadbandOLR-MEAN_GOES13
# Reflectance-650nm-MEAN_GOES13
# Temperature-10800nm-MEAN_GOES13
# TemperatureDifference-390nm-10800nm-MEAN_GOES13
# TemperatureDifference-10800nm-13300nm-MEAN_GOES13
# SOLZEN_GOES13
# WaterPercentage_GOES13
# ViewingZenithAngle_GOES13
# PHASE_GOES15
# IcingIndex_GOES15
# CloudOpticalDepth-MEAN_GOES15
# R-eff-MEAN_GOES15
# D-eff-MEAN_GOES15
# LWP-MEAN_GOES15
# IWP-MEAN_GOES15
# IR-emit-MEAN_GOES15
# T-eff-MEAN_GOES15
# Z-top-MEAN_GOES15
# Z-eff-MEAN_GOES15
# Z-bot-MEAN_GOES15
# Z-thk-MEAN_GOES15
# P-top-MEAN_GOES15
# P-eff-MEAN_GOES15
# P-bot-MEAN_GOES15
# BroadbandAlbedo-MEAN_GOES15
# BroadbandOLR-MEAN_GOES15
# Reflectance-650nm-MEAN_GOES15
# Temperature-10800nm-MEAN_GOES15
# TemperatureDifference-390nm-10800nm-MEAN_GOES15
# TemperatureDifference-10800nm-13300nm-MEAN_GOES15
# SOLZEN_GOES15
# WaterPercentage_GOES15
# ViewingZenithAngle_GOES15
# SulfOrgNitFrac_PALMS
# BioBurnFrac_PALMS
# SootFrac_PALMS
# MineralFrac_PALMS
# MeteoricFrac_PALMS
# SeaSaltFrac_PALMS
# OilCombFrac_PALMS
# UnclassFrac_PALMS
# OrgSulf-MF_PALMS
# IEPOX-MF_PALMS
# GAS-MF_PALMS
# SulfNeut_PALMS
# NPos_PALMS
# NNeg_PALMS
# NAcid_PALMS
# BUTENE-HN_CIT
# C3O3H6_CIT
# C4O3H6_CIT
# C4O3H8_CIT
# C4O4H7N_CIT
# C4O5H7N_CIT
# C5O3H10_CIT
# C5O3H8_CIT
# C5O5H9N_CIT
# ETHENE-HN_CIT
# ETHLN_CIT
# H2O_CIT
# H2O2_CIT
# HAC_CIT
# HCN_CIT
# HMHP_CIT
# HNO3_CIT
# IEPOX_CIT
# ISOPN_CIT
# ISOPOOH_CIT
# PAA_CIT
# PROPENE-HN_CIT
# PROPNN_CIT
# Acetaldehyde
# Acetone_Propanal
# Acetonitrile
# Benzene
# Isoprene-Furan
# Methanol
# Monoterpenes
# MVK_MAC
# Toluene
# CH4_seac4rs
# CO_obs
# OCS_WAS
# DMS_WAS
# CFC-12_WAS
# CFC-11_WAS
# CFC-113_WAS
# CFC-114_WAS
# HCFC-22_WAS
# HCFC-124_WAS
# HCFC-142b_WAS
# HCFC-141b_WAS
# HFC-134a_WAS
# HFC-152a_WAS
# H-1211_WAS
# H-2402_WAS
# H-1301_WAS
# CHBr3_WAS
# CHCl3_WAS
# CH3Cl_WAS
# CH3I_WAS
# CH3Br_WAS
# CH2Cl2_WAS
# CH2Br2_WAS
# C2HCl3_WAS
# CHBrCl2_WAS
# CHBr2Cl_WAS
# CCl4_WAS
# C2Cl4_WAS
# CH3CCl3_WAS
# 1_2-dichloroethane_WAS
# MeONO2_WAS
# EtONO2_WAS
# i-PrONO2_WAS
# n-PrONO2_WAS
# 2-BuONO2_WAS
# 3-Methyl-2-BuONO2_WAS
# 3-PenONO2_WAS
# 2-PeONO2_WAS
# Ethane_WAS
# Ethene_WAS
# Ethyne_WAS
# Propane_WAS
# Propene_WAS
# i-Butane_WAS
# n-Butane_WAS
# 1_2-Propadiene_WAS
# trans-2-Butene_WAS
# cis-2-Butene_WAS
# 1-Butene_WAS
# i-Butene_WAS
# Neopentane_WAS
# 1_3-Butadiene_WAS
# i-Pentane_WAS
# n-Pentane_WAS
# 1-Pentene_WAS
# Isoprene_WAS
# 2_3-Dimethylbutane_WAS
# 2-Methylpentane_WAS
# 3-Methylpentane_WAS
# n-Hexane_WAS
# n-Heptane_WAS
# Benzene_WAS
# Toluene_WAS
# Ethylbenzene_WAS
# m+p-Xylene_WAS
# o-Xylene_WAS
# alpha-Pinene_WAS
# beta-Pinene_WAS
# DN-IR-Irrad_BBR
# UP-IR-Irrad_BBR
# DN-Solar-Irrad_BBR
# UP-Solar-Irrad_BBR
# DN500nm_SSFR
# DN936nm_SSFR
# DN1600nm_SSFR
# DN350to700nm_SSFR
# DN350to2150nm_SSFR
# UP500nm_SSFR
# UP936nm_SSFR
# UP1600nm_SSFR
# UP350to700nm_SSFR
# UP350to2150nm_SSFR
# Flag_4STAR
# AerOptAmass_4STAR
# T4temp_4STAR
# ColumnWV_4STAR
# AOD-380nm_4STAR
# AOD-452nm_4STAR
# AOD-501nm_4STAR
# AOD-520nm_4STAR
# AOD-532nm_4STAR
# AOD-550nm_4STAR
# AOD-606nm_4STAR
# AOD-620nm_4STAR
# AOD-675nm_4STAR
# AOD-781nm_4STAR
# AOD-865nm_4STAR
# AOD-1020nm_4STAR
# AOD-1040nm_4STAR
# AOD-1064nm_4STAR
# AOD-1236nm_4STAR
# AOD-1559nm_4STAR
# AOD-1627nm_4STAR
# Rad-Max_4STAR-Zenith
# Rad-465nm_4STAR-Zenith
# Rad-500nm_4STAR-Zenith
# Rad-530nm_4STAR-Zenith
# Rad-555nm_4STAR-Zenith
# Rad-600nm_4STAR-Zenith
# Rad-610nm_4STAR-Zenith
# Rad-675nm_4STAR-Zenith
# Rad-870nm_4STAR-Zenith
# Rad-936nm_4STAR-Zenith
# Rad-1000nm_4STAR-Zenith
# Rad-1040nm_4STAR-Zenith
# Rad-1065nm_4STAR-Zenith
# Rad-1200nm_4STAR-Zenith
# Rad-1237nm_4STAR-Zenith
# Rad-1241nm_4STAR-Zenith
# Rad-1270nm_4STAR-Zenith
# Rad-1500nm_4STAR-Zenith
# Rad-1565nm_4STAR-Zenith
# Rad-1580nm_4STAR-Zenith
# Rad-1595nm_4STAR-Zenith
# Rad-1610nm_4STAR-Zenith
# Rad-1620nm_4STAR-Zenith
# Rad-1634nm_4STAR-Zenith
# Datetime_old_seac4rs
# Year_seac4rs
# Month_seac4rs
# Day_seac4rs
# Hour_seac4rs
# domain_indicator_seac4rs
# OH_obs
# Datetime_seac4rs
# FRACTIONAL_DAY
# DATE
# HOUR
# MINUTE
# LATITUDE
# LONGITUDE
# PRESSURE_geos-chem
# NO
# O3_geos-chem
# PAN_geos-chem
# CO_geos-chem
# ALK4
# ISOP
# HNO3
# H2O2
# ACET
# MEK
# ALD2
# RCHO
# MVK
# MACR
# PMN
# PPN
# R4N2
# PRPE
# C3H8
# CH2O
# C2H6
# N2O5
# HNO4
# MP
# DMS_seac4rs
# SO2
# SO4
# SO4s
# MSA
# NH3
# NH4
# NIT
# NITs
# BCPI
# OCPI
# BCPO
# OCPO
# DST1
# DST2
# DST3
# DST4
# SALA
# SALC
# Br2
# Br
# BrO
# HOBr
# HBr
# BrNO2
# BrNO3
# CHBr3
# CH2Br2
# CH3Br_seac4rs
# MPN
# ISOPN
# MOBA
# PROPNN
# HAC
# GLYC
# MMN
# RIP
# IEPOX
# MAP
# NO2
# NO3
# HNO2
# PCOFNE
# PCOFSE
# PCOFW
# PCOFRW
# PCOBCN
# PCOBSE
# PCOBW
# PCOBRW
# PISOP
# AVOC
# BBVOC
# ASOA
# BBSOA
# BGSOA
# OH_geos-chem
# HO2
# J_O1D
# GMAO_TEMP
# GMAO_ABSH
# GMAO_PSFC
# GMAO_UWND
# GMAO_VWND
# LAT_df
# LON_df
# ALT_df
# Datetime_df
# Datetime_old_df
# CH4_df
# CO2_df
# CO
# O3
# Ethane
# DMS_df
# CH3Br_df
# Year_df
# Month_df
# Day_df
# Hour_df
# domain_indicator_df
# Pressure_-24
# Potential_Temperature_-24
# Temperature_-24
# Rainfall_-24
# Mixing_Depth_-24
# Relative_Humidity_-24
# Specific_Humidity_-24
# Mixing_Ratio_-24
# Terrain_Altitude_-24
# Solar_Radiation_-24
# geometry_-24
# DateTime_-24
# Temperature_C_-24
# Distance_ptp_-24
# Cumulative_Dist_-24
# Dist_from_origin_-24
# bearings_from_origin_-24
# bearings_ptp_-24
# Moisture_Flux_-24
# Pressure_-23
# Potential_Temperature_-23
# Temperature_-23
# Rainfall_-23
# Mixing_Depth_-23
# Relative_Humidity_-23
# Specific_Humidity_-23
# Mixing_Ratio_-23
# Terrain_Altitude_-23
# Solar_Radiation_-23
# geometry_-23
# DateTime_-23
# Temperature_C_-23
# Distance_ptp_-23
# Cumulative_Dist_-23
# Dist_from_origin_-23
# bearings_from_origin_-23
# bearings_ptp_-23
# Moisture_Flux_-23
# Pressure_-22
# Potential_Temperature_-22
# Temperature_-22
# Rainfall_-22
# Mixing_Depth_-22
# Relative_Humidity_-22
# Specific_Humidity_-22
# Mixing_Ratio_-22
# Terrain_Altitude_-22
# Solar_Radiation_-22
# geometry_-22
# DateTime_-22
# Temperature_C_-22
# Distance_ptp_-22
# Cumulative_Dist_-22
# Dist_from_origin_-22
# bearings_from_origin_-22
# bearings_ptp_-22
# Moisture_Flux_-22
# Pressure_-21
# Potential_Temperature_-21
# Temperature_-21
# Rainfall_-21
# Mixing_Depth_-21
# Relative_Humidity_-21
# Specific_Humidity_-21
# Mixing_Ratio_-21
# Terrain_Altitude_-21
# Solar_Radiation_-21
# geometry_-21
# DateTime_-21
# Temperature_C_-21
# Distance_ptp_-21
# Cumulative_Dist_-21
# Dist_from_origin_-21
# bearings_from_origin_-21
# bearings_ptp_-21
# Moisture_Flux_-21
# Pressure_-20
# Potential_Temperature_-20
# Temperature_-20
# Rainfall_-20
# Mixing_Depth_-20
# Relative_Humidity_-20
# Specific_Humidity_-20
# Mixing_Ratio_-20
# Terrain_Altitude_-20
# Solar_Radiation_-20
# geometry_-20
# DateTime_-20
# Temperature_C_-20
# Distance_ptp_-20
# Cumulative_Dist_-20
# Dist_from_origin_-20
# bearings_from_origin_-20
# bearings_ptp_-20
# Moisture_Flux_-20
# Pressure_-19
# Potential_Temperature_-19
# Temperature_-19
# Rainfall_-19
# Mixing_Depth_-19
# Relative_Humidity_-19
# Specific_Humidity_-19
# Mixing_Ratio_-19
# Terrain_Altitude_-19
# Solar_Radiation_-19
# geometry_-19
# DateTime_-19
# Temperature_C_-19
# Distance_ptp_-19
# Cumulative_Dist_-19
# Dist_from_origin_-19
# bearings_from_origin_-19
# bearings_ptp_-19
# Moisture_Flux_-19
# Pressure_-18
# Potential_Temperature_-18
# Temperature_-18
# Rainfall_-18
# Mixing_Depth_-18
# Relative_Humidity_-18
# Specific_Humidity_-18
# Mixing_Ratio_-18
# Terrain_Altitude_-18
# Solar_Radiation_-18
# geometry_-18
# DateTime_-18
# Temperature_C_-18
# Distance_ptp_-18
# Cumulative_Dist_-18
# Dist_from_origin_-18
# bearings_from_origin_-18
# bearings_ptp_-18
# Moisture_Flux_-18
# Pressure_-17
# Potential_Temperature_-17
# Temperature_-17
# Rainfall_-17
# Mixing_Depth_-17
# Relative_Humidity_-17
# Specific_Humidity_-17
# Mixing_Ratio_-17
# Terrain_Altitude_-17
# Solar_Radiation_-17
# geometry_-17
# DateTime_-17
# Temperature_C_-17
# Distance_ptp_-17
# Cumulative_Dist_-17
# Dist_from_origin_-17
# bearings_from_origin_-17
# bearings_ptp_-17
# Moisture_Flux_-17
# Pressure_-16
# Potential_Temperature_-16
# Temperature_-16
# Rainfall_-16
# Mixing_Depth_-16
# Relative_Humidity_-16
# Specific_Humidity_-16
# Mixing_Ratio_-16
# Terrain_Altitude_-16
# Solar_Radiation_-16
# geometry_-16
# DateTime_-16
# Temperature_C_-16
# Distance_ptp_-16
# Cumulative_Dist_-16
# Dist_from_origin_-16
# bearings_from_origin_-16
# bearings_ptp_-16
# Moisture_Flux_-16
# Pressure_-15
# Potential_Temperature_-15
# Temperature_-15
# Rainfall_-15
# Mixing_Depth_-15
# Relative_Humidity_-15
# Specific_Humidity_-15
# Mixing_Ratio_-15
# Terrain_Altitude_-15
# Solar_Radiation_-15
# geometry_-15
# DateTime_-15
# Temperature_C_-15
# Distance_ptp_-15
# Cumulative_Dist_-15
# Dist_from_origin_-15
# bearings_from_origin_-15
# bearings_ptp_-15
# Moisture_Flux_-15
# Pressure_-14
# Potential_Temperature_-14
# Temperature_-14
# Rainfall_-14
# Mixing_Depth_-14
# Relative_Humidity_-14
# Specific_Humidity_-14
# Mixing_Ratio_-14
# Terrain_Altitude_-14
# Solar_Radiation_-14
# geometry_-14
# DateTime_-14
# Temperature_C_-14
# Distance_ptp_-14
# Cumulative_Dist_-14
# Dist_from_origin_-14
# bearings_from_origin_-14
# bearings_ptp_-14
# Moisture_Flux_-14
# Pressure_-13
# Potential_Temperature_-13
# Temperature_-13
# Rainfall_-13
# Mixing_Depth_-13
# Relative_Humidity_-13
# Specific_Humidity_-13
# Mixing_Ratio_-13
# Terrain_Altitude_-13
# Solar_Radiation_-13
# geometry_-13
# DateTime_-13
# Temperature_C_-13
# Distance_ptp_-13
# Cumulative_Dist_-13
# Dist_from_origin_-13
# bearings_from_origin_-13
# bearings_ptp_-13
# Moisture_Flux_-13
# Pressure_-12
# Potential_Temperature_-12
# Temperature_-12
# Rainfall_-12
# Mixing_Depth_-12
# Relative_Humidity_-12
# Specific_Humidity_-12
# Mixing_Ratio_-12
# Terrain_Altitude_-12
# Solar_Radiation_-12
# geometry_-12
# DateTime_-12
# Temperature_C_-12
# Distance_ptp_-12
# Cumulative_Dist_-12
# Dist_from_origin_-12
# bearings_from_origin_-12
# bearings_ptp_-12
# Moisture_Flux_-12
# Pressure_-11
# Potential_Temperature_-11
# Temperature_-11
# Rainfall_-11
# Mixing_Depth_-11
# Relative_Humidity_-11
# Specific_Humidity_-11
# Mixing_Ratio_-11
# Terrain_Altitude_-11
# Solar_Radiation_-11
# geometry_-11
# DateTime_-11
# Temperature_C_-11
# Distance_ptp_-11
# Cumulative_Dist_-11
# Dist_from_origin_-11
# bearings_from_origin_-11
# bearings_ptp_-11
# Moisture_Flux_-11
# Pressure_-10
# Potential_Temperature_-10
# Temperature_-10
# Rainfall_-10
# Mixing_Depth_-10
# Relative_Humidity_-10
# Specific_Humidity_-10
# Mixing_Ratio_-10
# Terrain_Altitude_-10
# Solar_Radiation_-10
# geometry_-10
# DateTime_-10
# Temperature_C_-10
# Distance_ptp_-10
# Cumulative_Dist_-10
# Dist_from_origin_-10
# bearings_from_origin_-10
# bearings_ptp_-10
# Moisture_Flux_-10
# Pressure_-9
# Potential_Temperature_-9
# Temperature_-9
# Rainfall_-9
# Mixing_Depth_-9
# Relative_Humidity_-9
# Specific_Humidity_-9
# Mixing_Ratio_-9
# Terrain_Altitude_-9
# Solar_Radiation_-9
# geometry_-9
# DateTime_-9
# Temperature_C_-9
# Distance_ptp_-9
# Cumulative_Dist_-9
# Dist_from_origin_-9
# bearings_from_origin_-9
# bearings_ptp_-9
# Moisture_Flux_-9
# Pressure_-8
# Potential_Temperature_-8
# Temperature_-8
# Rainfall_-8
# Mixing_Depth_-8
# Relative_Humidity_-8
# Specific_Humidity_-8
# Mixing_Ratio_-8
# Terrain_Altitude_-8
# Solar_Radiation_-8
# geometry_-8
# DateTime_-8
# Temperature_C_-8
# Distance_ptp_-8
# Cumulative_Dist_-8
# Dist_from_origin_-8
# bearings_from_origin_-8
# bearings_ptp_-8
# Moisture_Flux_-8
# Pressure_-7
# Potential_Temperature_-7
# Temperature_-7
# Rainfall_-7
# Mixing_Depth_-7
# Relative_Humidity_-7
# Specific_Humidity_-7
# Mixing_Ratio_-7
# Terrain_Altitude_-7
# Solar_Radiation_-7
# geometry_-7
# DateTime_-7
# Temperature_C_-7
# Distance_ptp_-7
# Cumulative_Dist_-7
# Dist_from_origin_-7
# bearings_from_origin_-7
# bearings_ptp_-7
# Moisture_Flux_-7
# Pressure_-6
# Potential_Temperature_-6
# Temperature_-6
# Rainfall_-6
# Mixing_Depth_-6
# Relative_Humidity_-6
# Specific_Humidity_-6
# Mixing_Ratio_-6
# Terrain_Altitude_-6
# Solar_Radiation_-6
# geometry_-6
# DateTime_-6
# Temperature_C_-6
# Distance_ptp_-6
# Cumulative_Dist_-6
# Dist_from_origin_-6
# bearings_from_origin_-6
# bearings_ptp_-6
# Moisture_Flux_-6
# Pressure_-5
# Potential_Temperature_-5
# Temperature_-5
# Rainfall_-5
# Mixing_Depth_-5
# Relative_Humidity_-5
# Specific_Humidity_-5
# Mixing_Ratio_-5
# Terrain_Altitude_-5
# Solar_Radiation_-5
# geometry_-5
# DateTime_-5
# Temperature_C_-5
# Distance_ptp_-5
# Cumulative_Dist_-5
# Dist_from_origin_-5
# bearings_from_origin_-5
# bearings_ptp_-5
# Moisture_Flux_-5
# Pressure_-4
# Potential_Temperature_-4
# Temperature_-4
# Rainfall_-4
# Mixing_Depth_-4
# Relative_Humidity_-4
# Specific_Humidity_-4
# Mixing_Ratio_-4
# Terrain_Altitude_-4
# Solar_Radiation_-4
# geometry_-4
# DateTime_-4
# Temperature_C_-4
# Distance_ptp_-4
# Cumulative_Dist_-4
# Dist_from_origin_-4
# bearings_from_origin_-4
# bearings_ptp_-4
# Moisture_Flux_-4
# Pressure_-3
# Potential_Temperature_-3
# Temperature_-3
# Rainfall_-3
# Mixing_Depth_-3
# Relative_Humidity_-3
# Specific_Humidity_-3
# Mixing_Ratio_-3
# Terrain_Altitude_-3
# Solar_Radiation_-3
# geometry_-3
# DateTime_-3
# Temperature_C_-3
# Distance_ptp_-3
# Cumulative_Dist_-3
# Dist_from_origin_-3
# bearings_from_origin_-3
# bearings_ptp_-3
# Moisture_Flux_-3
# Pressure_-2
# Potential_Temperature_-2
# Temperature_-2
# Rainfall_-2
# Mixing_Depth_-2
# Relative_Humidity_-2
# Specific_Humidity_-2
# Mixing_Ratio_-2
# Terrain_Altitude_-2
# Solar_Radiation_-2
# geometry_-2
# DateTime_-2
# Temperature_C_-2
# Distance_ptp_-2
# Cumulative_Dist_-2
# Dist_from_origin_-2
# bearings_from_origin_-2
# bearings_ptp_-2
# Moisture_Flux_-2
# Pressure_-1
# Potential_Temperature_-1
# Temperature_-1
# Rainfall_-1
# Mixing_Depth_-1
# Relative_Humidity_-1
# Specific_Humidity_-1
# Mixing_Ratio_-1
# Terrain_Altitude_-1
# Solar_Radiation_-1
# geometry_-1
# DateTime_-1
# Temperature_C_-1
# Distance_ptp_-1
# Cumulative_Dist_-1
# Dist_from_origin_-1
# bearings_from_origin_-1
# bearings_ptp_-1
# Moisture_Flux_-1
# Pressure_0
# Potential_Temperature_0
# Temperature_0
# Rainfall_0
# Mixing_Depth_0
# Relative_Humidity_0
# Specific_Humidity_0
# Mixing_Ratio_0
# Terrain_Altitude_0
# Solar_Radiation_0
# geometry_0
# DateTime_0
# Temperature_C_0
# Distance_ptp_0
# Cumulative_Dist_0
# Dist_from_origin_0
# bearings_from_origin_0
# bearings_ptp_0
# Moisture_Flux_0
# Longitude_-24
# Latitude_-24
# AltP_meters_-24
# Longitude_-23
# Latitude_-23
# AltP_meters_-23
# Longitude_-22
# Latitude_-22
# AltP_meters_-22
# Longitude_-21
# Latitude_-21
# AltP_meters_-21
# Longitude_-20
# Latitude_-20
# AltP_meters_-20
# Longitude_-19
# Latitude_-19
# AltP_meters_-19
# Longitude_-18
# Latitude_-18
# AltP_meters_-18
# Longitude_-17
# Latitude_-17
# AltP_meters_-17
# Longitude_-16
# Latitude_-16
# AltP_meters_-16
# Longitude_-15
# Latitude_-15
# AltP_meters_-15
# Longitude_-14
# Latitude_-14
# AltP_meters_-14
# Longitude_-13
# Latitude_-13
# AltP_meters_-13
# Longitude_-12
# Latitude_-12
# AltP_meters_-12
# Longitude_-11
# Latitude_-11
# AltP_meters_-11
# Longitude_-10
# Latitude_-10
# AltP_meters_-10
# Longitude_-9
# Latitude_-9
# AltP_meters_-9
# Longitude_-8
# Latitude_-8
# AltP_meters_-8
# Longitude_-7
# Latitude_-7
# AltP_meters_-7
# Longitude_-6
# Latitude_-6
# AltP_meters_-6
# Longitude_-5
# Latitude_-5
# AltP_meters_-5
# Longitude_-4
# Latitude_-4
# AltP_meters_-4
# Longitude_-3
# Latitude_-3
# AltP_meters_-3
# Longitude_-2
# Latitude_-2
# AltP_meters_-2
# Longitude_-1
# Latitude_-1
# AltP_meters_-1
# Longitude_0
# Latitude_0
# AltP_meters_0
# lat_lon_interaction_0
# lat_diff
# lon_diff
# straight_line_efficiency_ratio
# dew_point_-24
# dew_point_-23
# dew_point_-22
# dew_point_-21
# dew_point_-20
# dew_point_-19
# dew_point_-18
# dew_point_-17
# dew_point_-16
# dew_point_-15
# dew_point_-14
# dew_point_-13
# dew_point_-12
# dew_point_-11
# dew_point_-10
# dew_point_-9
# dew_point_-8
# dew_point_-7
# dew_point_-6
# dew_point_-5
# dew_point_-4
# dew_point_-3
# dew_point_-2
# dew_point_-1
# dew_point_0
# LCL_-24
# LCL_-23
# LCL_-22
# LCL_-21
# LCL_-20
# LCL_-19
# LCL_-18
# LCL_-17
# LCL_-16
# LCL_-15
# LCL_-14
# LCL_-13
# LCL_-12
# LCL_-11
# LCL_-10
# LCL_-9
# LCL_-8
# LCL_-7
# LCL_-6
# LCL_-5
# LCL_-4
# LCL_-3
# LCL_-2
# LCL_-1
# LCL_0
# Rainfall_Estimate_-24
# Rainfall_Estimate_-23
# Rainfall_Estimate_-22
# Rainfall_Estimate_-21
# Rainfall_Estimate_-20
# Rainfall_Estimate_-19
# Rainfall_Estimate_-18
# Rainfall_Estimate_-17
# Rainfall_Estimate_-16
# Rainfall_Estimate_-15
# Rainfall_Estimate_-14
# Rainfall_Estimate_-13
# Rainfall_Estimate_-12
# Rainfall_Estimate_-11
# Rainfall_Estimate_-10
# Rainfall_Estimate_-9
# Rainfall_Estimate_-8
# Rainfall_Estimate_-7
# Rainfall_Estimate_-6
# Rainfall_Estimate_-5
# Rainfall_Estimate_-4
# Rainfall_Estimate_-3
# Rainfall_Estimate_-2
# Rainfall_Estimate_-1
# Rainfall_Estimate_0
# time_difference_-24
# time_difference_seconds_-24
# hour_sin_-24
# hour_cos_-24
# month_sin_-24
# month_cos_-24
# time_difference_-23
# time_difference_seconds_-23
# hour_sin_-23
# hour_cos_-23
# month_sin_-23
# month_cos_-23
# time_difference_-22
# time_difference_seconds_-22
# hour_sin_-22
# hour_cos_-22
# month_sin_-22
# month_cos_-22
# time_difference_-21
# time_difference_seconds_-21
# hour_sin_-21
# hour_cos_-21
# month_sin_-21
# month_cos_-21
# time_difference_-20
# time_difference_seconds_-20
# hour_sin_-20
# hour_cos_-20
# month_sin_-20
# month_cos_-20
# time_difference_-19
# time_difference_seconds_-19
# hour_sin_-19
# hour_cos_-19
# month_sin_-19
# month_cos_-19
# time_difference_-18
# time_difference_seconds_-18
# hour_sin_-18
# hour_cos_-18
# month_sin_-18
# month_cos_-18
# time_difference_-17
# time_difference_seconds_-17
# hour_sin_-17
# hour_cos_-17
# month_sin_-17
# month_cos_-17
# time_difference_-16
# time_difference_seconds_-16
# hour_sin_-16
# hour_cos_-16
# month_sin_-16
# month_cos_-16
# time_difference_-15
# time_difference_seconds_-15
# hour_sin_-15
# hour_cos_-15
# month_sin_-15
# month_cos_-15
# time_difference_-14
# time_difference_seconds_-14
# hour_sin_-14
# hour_cos_-14
# month_sin_-14
# month_cos_-14
# time_difference_-13
# time_difference_seconds_-13
# hour_sin_-13
# hour_cos_-13
# month_sin_-13
# month_cos_-13
# time_difference_-12
# time_difference_seconds_-12
# hour_sin_-12
# hour_cos_-12
# month_sin_-12
# month_cos_-12
# time_difference_-11
# time_difference_seconds_-11
# hour_sin_-11
# hour_cos_-11
# month_sin_-11
# month_cos_-11
# time_difference_-10
# time_difference_seconds_-10
# hour_sin_-10
# hour_cos_-10
# month_sin_-10
# month_cos_-10
# time_difference_-9
# time_difference_seconds_-9
# hour_sin_-9
# hour_cos_-9
# month_sin_-9
# month_cos_-9
# time_difference_-8
# time_difference_seconds_-8
# hour_sin_-8
# hour_cos_-8
# month_sin_-8
# month_cos_-8
# time_difference_-7
# time_difference_seconds_-7
# hour_sin_-7
# hour_cos_-7
# month_sin_-7
# month_cos_-7
# time_difference_-6
# time_difference_seconds_-6
# hour_sin_-6
# hour_cos_-6
# month_sin_-6
# month_cos_-6
# time_difference_-5
# time_difference_seconds_-5
# hour_sin_-5
# hour_cos_-5
# month_sin_-5
# month_cos_-5
# time_difference_-4
# time_difference_seconds_-4
# hour_sin_-4
# hour_cos_-4
# month_sin_-4
# month_cos_-4
# time_difference_-3
# time_difference_seconds_-3
# hour_sin_-3
# hour_cos_-3
# month_sin_-3
# month_cos_-3
# time_difference_-2
# time_difference_seconds_-2
# hour_sin_-2
# hour_cos_-2
# month_sin_-2
# month_cos_-2
# time_difference_-1
# time_difference_seconds_-1
# hour_sin_-1
# hour_cos_-1
# month_sin_-1
# month_cos_-1
# time_difference_0
# time_difference_seconds_0
# hour_sin_0
# hour_cos_0
# month_sin_0
# month_cos_0
# std_pressure
# delta_pressure
# mean_pressure
# sum_pressure
# std_potential_temperature
# delta_potential_temperature
# mean_potential_temperature
# sum_potential_temperature
# std_relative_humidity
# delta_relative_humidity
# mean_relative_humidity
# sum_relative_humidity
# std_specific_humidity
# delta_specific_humidity
# mean_specific_humidity
# sum_specific_humidity
# std_solar_radiation
# delta_solar_radiation
# mean_solar_radiation
# sum_solar_radiation
# std_mixing_depth
# delta_mixing_depth
# mean_mixing_depth
# sum_mixing_depth
# std_moisture_flux
# delta_moisture_flux
# mean_moisture_flux
# sum_moisture_flux
# std_temperature_c
# delta_temperature_c
# mean_temperature_c
# sum_temperature_c
# std_rainfall_estimate
# delta_rainfall_estimate
# mean_rainfall_estimate
# sum_rainfall_estimate
# std_lcl
# delta_lcl
# mean_lcl
# sum_lcl
# std_dew_point
# delta_dew_point
# mean_dew_point
# sum_dew_point
# std_latitude
# delta_latitude
# mean_latitude
# sum_latitude
# std_longitude
# delta_longitude
# mean_longitude
# sum_longitude
# Velocity_-24
# Velocity_-23
# Velocity_-22
# Velocity_-21
# Velocity_-20
# Velocity_-19
# Velocity_-18
# Velocity_-17
# Velocity_-16
# Velocity_-15
# Velocity_-14
# Velocity_-13
# Velocity_-12
# Velocity_-11
# Velocity_-10
# Velocity_-9
# Velocity_-8
# Velocity_-7
# Velocity_-6
# Velocity_-5
# Velocity_-4
# Velocity_-3
# Velocity_-2
# Velocity_-1
# std_velocity
# delta_velocity
# mean_velocity
# domain_label
# spatial_cluster
# kfold_Longitude
# kfold_cluster
# min_distance_to_cluster_centroids
# mean_distance_to_cluster_centroids
# min_distance_to_t1000_cities
# mean_distance_to_t1000_cities
# min_distance_to_extent_corners
# mean_distance_to_extent_corners
# min_distance_to_antimeridian
# mean_distance_to_antimeridian
# PASTEL_CO
# PASTEL_CH4
# PASTEL_Ethane
# PASTEL_DMS
# PASTEL_CH3Br
# PASTEL_O3

# %%
seac4rs_f["CH3Br_seac4rs"] = seac4rs_f["CH3Br_seac4rs"] * 1e3
seac4rs_f["C2H6"] = seac4rs_f["C2H6"] * 1e3
seac4rs_f["DMS_seac4rs"] = seac4rs_f["DMS_seac4rs"] * 1e3

# %%
ATS_names = ["CO", "CH4", "CH3Br", "DMS", "O3", "Ethane"]

# Create a mapping of names to specific column names for the GMI and PASTEL models
model_mapping = {
    # "CO": ("CO_obs", "CO_geos-chem", "PASTEL_CO"),
    "CH3Br": ("CH3Br_df", "CH3Br_seac4rs", "PASTEL_CH3Br"),
    "Ethane": ("Ethane", "C2H6", "PASTEL_Ethane"),
    "O3": ("O3", "O3_geos-chem", "PASTEL_O3"),
    "DMS" : ("DMS_df", "DMS_seac4rs", "PASTEL_DMS"),
}

# Initialize an empty list to store results
metrics_list = []

# Loop through species and calculate metrics
for species, (data_col, seac4rs_col, pastel_col) in model_mapping.items():
    # Drop NaN values from both data and target columns
    merged_seac4rs = pd.concat([seac4rs_f[data_col], seac4rs_f[seac4rs_col]], axis=1).dropna()

    if species == 'DMS':
        merged_seac4rs = merged_seac4rs[merged_seac4rs[seac4rs_col] >= 1]

    merged_pastel = pd.concat([seac4rs_f[data_col], seac4rs_f[pastel_col]], axis=1).dropna()
    
    # Ensure the same rows are kept in both DataFrames (i.e., intersection of indexes)
    merged_seac4rs = merged_seac4rs.loc[merged_seac4rs.index.intersection(merged_pastel.index)]
    
    print(len(merged_seac4rs))

    # scatter_plot(merged_seac4rs[data_col], merged_seac4rs[seac4rs_col], "seac4rs_scatter", species)
    # scatter_plot(merged_pastel[data_col], merged_pastel[pastel_col], "pastel_sctter", species)

    # Calculate metrics for GMI and PASTEL after dropping NaN
    metrics_list.append(
        calculate_and_organize_metrics_model(merged_seac4rs[data_col], merged_seac4rs[seac4rs_col], "GEOS-Chem", species)
    )
    metrics_list.append(
        calculate_and_organize_metrics_model(merged_pastel[data_col], merged_pastel[pastel_col], "PASTEL", species)
    )

# Combine all metrics into a single DataFrame
model_metrics = pd.concat(metrics_list, ignore_index=True)

model_metrics[['Model', 'ATS', 'RMSE', 'MAE', "R2"]]
# Out:
# 473
# 465
# 467
# 11
#        Model     ATS         RMSE         MAE        R2
# 0  GEOS-Chem   CH3Br     3.630744    1.149814  0.005336
# 1     PASTEL   CH3Br     3.786270    1.408916 -0.081703
# 2  GEOS-Chem  Ethane  1401.215634  896.087849 -0.475390
# 3     PASTEL  Ethane  1384.939133  959.444542 -0.441313
# 4  GEOS-Chem      O3    17.830626   13.588456  0.215829
# 5     PASTEL      O3    30.693972   22.835491 -1.323721
# 6  GEOS-Chem     DMS    18.092392   14.162455 -0.102566
# 7     PASTEL     DMS    15.710799    9.872827 -1.772297

# %%
for c in korusaq_f.columns:
    print(c)
# Out:
# iindex
# Fractional_Day
# STARTTIME
# STOPTIME
# UTC_obs
# JDAY
# INDEX
# FLIGHT
# LOCAL_SUN_TIME
# LAT_korusaq
# LON_korusaq
# ALT_korusaq
# PRESSURE
# TEMPERATURE
# THETA
# O3COLUMN
# SZA
# WNS
# WND
# MSL_GPS_ALT
# HAE_GPS_ALT
# Radar_ALT
# GRD_SPD
# TAS
# IAS
# MachNumber
# VerticalSpeed
# HDG
# TRK
# DriftAngle
# PITCH
# ROLL
# PotentialTemp_Hskping
# Dewpoint
# TotalAirTemp
# IR_SurfTemp
# CabinPressure
# SolarZenithAngle
# AircraftSunElevation
# SunAzimuth
# AircraftSunAzimuth
# H2O_MixingRatio_Hskping
# H2O_VaporPressure_Hskping
# H2O_SatVaporPressureWater_Hskping
# H2O_SatVaporPressureIce_Hskping
# H2O_RelativeHumidity_Hskping
# ProfileNumber
# SiteNumber
# MissedApproachNumber
# H2O_MixingRatio_DLH
# H2O_RelativeHumidityIce_DLH
# H2O_RelativeHumidityWater_DLH
# CO_korusaq
# CH4_korusaq
# N2O_MixingRatio
# CO2_korusaq
# CH2O_CAMS
# C2H6_CAMS
# NO2_KACES
# CHOCHO_KACES
# Flag_KACES
# NO_MixingRatio
# NOy_MixingRatio
# NO2_MixingRatio
# O3_korusaq
# NO2_MixingRatio_LIF
# PNs_MixingRatio_LIF
# ANs_MixingRatio_LIF
# apANs_MixingRatio_TDLIF
# PAN
# PPN_GTCIMS
# APAN_GTCIMS
# PBZN_GTCIMS
# SO2_GTCIMS
# HCl_GTCIMS
# ClNO2_KCIMS
# Cl2_KCIMS
# J[O3->O2+O(1D)]
# J[NO2->NO+O(3P)]
# J[H2O2->2OH]
# J[NO3->NO+O2]
# J[NO3->NO2+O(3P)]
# J[N2O5->NO3+NO2]
# J[HNO2->OH+NO]
# J[HNO3->OH+NO2]
# J[HNO4->HO2+NO2(UV_VISonly)]
# J[CH2O->H+HCO]
# J[CH2O->H2+CO]
# J[CH3CHO->CH3+HCO]
# J[C2H5CHO->C2H5+HCO]
# J[CH3OOH->CH3O+OH]
# J[CH3ONO2->CH3O+NO2]
# J[CH3CH2ONO2->CH3CH2O+NO2]
# J[CH3CO(OONO2)->CH3CO(OO)+NO2]
# J[CH3CO(OONO2)->CH3CO(O)+NO3]
# J[MAC->Products]
# J[MVK->Products]
# J[CH3COCH3->CH3CO+CH3]
# J[CH3COCH2CH3->CH3CO+CH2CH3]
# J[CH2(OH)COCH3->CH3CO+CH2(OH)]
# J[CH2(OH)COCH3->CH2(OH)CO+CH3]
# J[CHOCHO->HCO+HCO]
# J[CHOCHO->H2+2CO]
# J[CHOCHO->CH2O+CO]
# J[CH3COCHO->CH3CO+HCO]
# J[CH3COCOCH3->Products]
# J[Cl2->Cl+Cl]
# J[ClO->Cl+O(3P)]
# J[ClNO2->Cl+NO2]
# J[ClONO->Cl+NO2]
# J[ClONO2->Cl+NO3]
# J[ClONO2->ClO+NO2]
# J[Br2->Br+Br]
# J[BrO->Br+O]
# J[HOBr->OH+Br]
# J[BrNO->Br+NO]
# J[BrONO->Br+NO2]
# J[BrONO->BrO+NO]
# J[BrNO2->Br+NO2]
# J[BrONO2->BrO+NO2]
# J[BrONO2->Br+NO3]
# J[BrCl->Br+Cl]
# J[CHBr3->Products]
# jO3_DownwellingFraction
# jNO2_DownwellingFraction
# QualityFlag_CAFS
# OH
# HO2_MixingRatio
# OH_Interference
# OH_Reactivity
# Org-lt-1um_AMS-60s
# Sulfate-lt-1um_AMS-60s
# Ammonium-lt-1um_AMS-60s
# Nitrate-lt-1um_AMS-60s
# Chloride-lt-1um_AMS-60s
# stdPT-to-AMB_Conversion_AMS-60s
# IceFlag_AMS-60s
# AmmoniumBalance-lt-1um_AMS-60s
# Density-lt-1um_AMS-60s
# OADensity-lt-1um_AMS-60s
# OtoC-ratio-lt-1um_AMS-60s
# HtoC-ratio-lt-1um_AMS-60s
# OAtoOC-ratio-lt-1um_AMS-60s
# OxidationState-lt-1um_AMS-60s
# f43-lt-1um_AMS-60s
# f44-lt-1um_AMS-60s
# f57-lt-1um_AMS-60s
# f60-lt-1um_AMS-60s
# f82-lt-1um_AMS-60s
# f91-lt-1um_AMS-60s
# fC2H3O-lt-1um_AMS-60s
# fCO2-lt-1um_AMS-60s
# fC4H9-lt-1um_AMS-60s
# fC2H4O2-lt-1um_AMS-60s
# fC5H6O-lt-1um_AMS-60s
# fC7H7-lt-1um_AMS-60s
# OrgNitrateFraction-lt-1um_AMS-60s
# Org-lt-1um_KAMS
# Nitrate-lt-1um_KAMS
# Sulfate-lt-1um_KAMS
# Ammonium-lt-1um_KAMS
# Chloride-lt-1um_KAMS
# HNO3_NO3-lt1um_SAGA
# Sulfate-lt1um_SAGA
# Cl_SAGA-AERO
# Br_SAGA-AERO
# NO3_SAGA-AERO
# SO4_SAGA-AERO
# C2O4_SAGA-AERO
# Na_SAGA-AERO
# NH4_SAGA-AERO
# K_SAGA-AERO
# Mg_SAGA-AERO
# Ca_SAGA-AERO
# BCmass_100to500nm_HDSP2
# BC_FracIM_HDSP2
# BC_CoatingThickness_HDSP2
# BC_fRH_HDSP2
# SCAT450nm-dry_total_stdPT_LARGE
# SCAT550nm-dry_total_stdPT_LARGE
# SCAT700nm-dry_total_stdPT_LARGE
# ABS470nm-dry_total_stdPT_LARGE
# ABS532nm-dry_total_stdPT_LARGE
# ABS660nm-dry_total_stdPT_LARGE
# gamma-450nm_LARGE
# gamma-550nm_LARGE
# gamma-700nm_LARGE
# fRH-450nm_RH20to80_LARGE
# fRH-550nm_RH20to80_LARGE
# fRH-700nm_RH20to80_LARGE
# SCAT450nm-amb_total_stdPT_LARGE
# SCAT550nm-amb_total_stdPT_LARGE
# SCAT700nm-amb_total_stdPT_LARGE
# AE-dry_SCAT_450to550nm_LARGE
# SSA450nm-dry_LARGE
# SSA550nm-dry_LARGE
# SSA700nm-dry_LARGE
# SSA450nm-amb_LARGE
# SSA550nm-amb_LARGE
# SSA700nm-amb_LARGE
# EXT532nm-dry_stdPT_LARGE
# EXT532nm-amb_stdPT_LARGE
# CNgt3nm_stdPT_LARGE
# CNgt10nm_stdPT_LARGE
# CNgt10nm_nonvol_stdPT_LARGE
# CNgt10nm_KCCN-CPC
# CCNconc_06SS
# IntegN_Dmob10to200nm_stdPT_SMPS_LARGE
# IntegV_Dmob10to200nm_stdPT_SMPS_LARGE
# IntegN_100to5000nm_stdPT_LAS_LARGE
# IntegV_100to5000nm_stdPT_LAS_LARGE
# IntegN_Daero500to5000nm_stdPT_APS_LARGE
# IntegV_Daero500to5000nm_stdPT_APS_LARGE
# IntegN_800to50000nm_stdPT_CPSPD_LARGE
# IntegV_800to50000nm_stdPT_CPSPD_LARGE
# AMB-to-stdPT_Conversion_LARGE
# CloudFlag
# CWC
# BUTENE-HN_CIT
# C3O3H6_CIT
# C4O4H7N_CIT
# C5O3H10_CIT
# CH3OOH_CIT
# CRESOL_CIT
# DHT_CIT
# ETHENE-HN_CIT
# ETHLN_CIT
# GLYC_CIT
# H2O2_CIT
# HAC_CIT
# HCN_CIT
# HMHP_CIT
# HNO3_CIT
# IEPOX_CIT
# ISOPN_CIT
# ISOPOOH_CIT
# PAA_CIT
# PROPENE-HN_CIT
# PROPNN_CIT
# Methanol_PTRMS
# Acetonitrile_PTRMS
# Acetaldehyde_PTRMS
# Acetone_Propanal_PTRMS
# Isoprene_PTRMS
# MVK_MACR_ISOPOOH_PTRMS
# MEK_PTRMS
# Benzene_PTRMS
# Toluene_PTRMS
# C8-alkylbenzenes_PTRMS
# Monoterpenes_PTRMS
# Toluene_KPTRMS
# OCS_WAS
# DMS_WAS
# CFC-12_WAS
# CFC-11_WAS
# CFC-113_WAS
# CFC-114_WAS
# CFC-112_WAS
# H-1211_WAS
# H-2402_WAS
# H-1301_WAS
# HFC-152a_WAS
# HFC-134a_WAS
# HCFC-22_WAS
# HCFC-142b_WAS
# HCFC-141b_WAS
# HFC-227ea_WAS
# HFC-365mfc_WAS
# CHCl3_WAS
# CH3CCl3_WAS
# CCl4_WAS
# CH2Cl2_WAS
# C2HCl3_WAS
# C2Cl4_WAS
# CH3Cl_WAS
# CH3Br_WAS
# CH3I_WAS
# CH2Br2_WAS
# CHBrCl2_WAS
# CHBr2Cl_WAS
# CHBr3_WAS
# 1-2-Dichloroethane_WAS
# MeONO2_WAS
# EtONO2_WAS
# i-PrONO2_WAS
# n-PrONO2_WAS
# 2-BuONO2_WAS
# 3-PeONO2_WAS
# 2-PeONO2_WAS
# 3-Methyl-2-BuONO2_WAS
# Ethane_WAS
# Ethene_WAS
# Ethyne_WAS
# Propane_WAS
# Propene_WAS
# i-Butane_WAS
# n-Butane_WAS
# 1-Butene_WAS
# i-Butene_WAS
# trans-2-Butene_WAS
# cis-2-Butene_WAS
# i-Pentane_WAS
# n-Pentane_WAS
# 1-3-Butadiene_WAS
# Isoprene_WAS
# n-Hexane_WAS
# n-Heptane_WAS
# n-Octane_WAS
# n-Nonane_WAS
# n-Decane_WAS
# 2-3-Dimethylbutane_WAS
# 2-Methylpentane_WAS
# 3-Methylpentane_WAS
# Cyclopentane_WAS
# Methylcyclopentane_WAS
# Cyclohexane_WAS
# Methylcylohexane_WAS
# Benzene_WAS
# Toluene_WAS
# Ethylbenzene_WAS
# m/p-Xylene_WAS
# o-Xylene_WAS
# Styrene_WAS
# i-Propylbenzene_WAS
# n-Propylbenzene_WAS
# 3-Ethyltoluene_WAS
# 4-Ethyltoluene_WAS
# 2-Ethyltoluene_WAS
# 1-3-5-Trimethylbenzene_WAS
# 1-2-4-Trimethylbenzene_WAS
# 1-2-3-Trimethylbenzene_WAS
# alpha-Pinene_WAS
# beta-Pinene_WAS
# H2_WAS
# AOD-QualFlag_4STAR
# AerosolOpticalAirmass_4STAR
# AOD-380nm_4STAR
# AOD-452nm_4STAR
# AOD-501nm_4STAR
# AOD-520nm_4STAR
# AOD-532nm_4STAR
# AOD-550nm_4STAR
# AOD-606nm_4STAR
# AOD-620nm_4STAR
# AOD-675nm_4STAR
# AOD-781nm_4STAR
# AOD-865nm_4STAR
# AOD-1020nm_4STAR
# AOD-1040nm_4STAR
# AOD-1064nm_4STAR
# AOD-1236nm_4STAR
# AOD-1559nm_4STAR
# AOD-1627nm_4STAR
# O3-OpticalAirmass_4STAR
# NO2-OpticalAirmass_4STAR
# ColumnWV_4STAR
# ColumnWV-QA_4STAR
# ColumnO3_4STAR
# ColumnO3-QA_4STAR
# ColumnNO2_4STAR
# ColumnNO2-QA_4STAR
# domain_indicator_korusaq
# Datetime_old_korusaq
# Year_korusaq
# Month_korusaq
# Day_korusaq
# Hour_korusaq
# Datetime_korusaq
# UTC_MICP
# LATITUDE
# LONGITUDE
# ALTP
# ps_GEOSChemSNU
# tmp_GEOSChemSNU
# rh_GEOSChemSNU
# uwnd_GEOSChemSNU
# vwnd_GEOSChemSNU
# vmro3_GEOSChemSNU
# vmrco_GEOSChemSNU
# vmrno_GEOSChemSNU
# vmrno2_GEOSChemSNU
# vmrno3_GEOSChemSNU
# vmrhno3_GEOSChemSNU
# vmrpan_GEOSChemSNU
# vmrorgnit_GEOSChemSNU
# vmrhono_GEOSChemSNU
# vmrhno4_GEOSChemSNU
# vmrn2o5_GEOSChemSNU
# vmroh_GEOSChemSNU
# vmrh2o2_GEOSChemSNU
# vmrho2_GEOSChemSNU
# vmrnh3_GEOSChemSNU
# vmrso2_GEOSChemSNU
# vmrdms_GEOSChemSNU
# vmrc2h6_GEOSChemSNU
# vmrc3h8_GEOSChemSNU
# vmrc2h4_GEOSChemSNU
# vmrc3h6_GEOSChemSNU
# vmralkanes_GEOSChemSNU
# vmralkenes_GEOSChemSNU
# vmrhcho_GEOSChemSNU
# vmrch3cho_GEOSChemSNU
# vmracetone_GEOSChemSNU
# vmrmethanol_GEOSChemSNU
# vmrtoluene_GEOSChemSNU
# vmrbenzene_GEOSChemSNU
# vmrxylene_GEOSChemSNU
# vmrisop_GEOSChemSNU
# vmrtp_GEOSChemSNU
# vmrc10h16_GEOSChemSNU
# nitrate_GEOSChemSNU
# so4_GEOSChemSNU
# bc_GEOSChemSNU
# poa_GEOSChemSNU
# seasalt_GEOSChemSNU
# dust_GEOSChemSNU
# nh4_GEOSChemSNU
# soa_GEOSChemSNU
# noy_GEOSChemSNU
# ps_CAMChemNCAR
# tmp_CAMChemNCAR
# uwnd_CAMChemNCAR
# vwnd_CAMChemNCAR
# rh_CAMChemNCAR
# jno2_CAMChemNCAR
# jo3o1d_CAMChemNCAR
# vmro3_CAMChemNCAR
# vmrco_CAMChemNCAR
# vmrno_CAMChemNCAR
# vmrno2_CAMChemNCAR
# vmrhno3_CAMChemNCAR
# vmrpan_CAMChemNCAR
# vmrno3_CAMChemNCAR
# vmrn2o5_CAMChemNCAR
# vmrorgnit_CAMChemNCAR
# vmrhno4_CAMChemNCAR
# vmroh_CAMChemNCAR
# vmrh2o2_CAMChemNCAR
# vmrho2_CAMChemNCAR
# vmrnh3_CAMChemNCAR
# vmrso2_CAMChemNCAR
# vmrdms_CAMChemNCAR
# vmrc2h6_CAMChemNCAR
# vmrc3h8_CAMChemNCAR
# vmrc2h4_CAMChemNCAR
# vmrc3h6_CAMChemNCAR
# vmralkanes_CAMChemNCAR
# vmralkenes_CAMChemNCAR
# vmrhcho_CAMChemNCAR
# vmrch3cho_CAMChemNCAR
# vmracetone_CAMChemNCAR
# vmrglyoxal_CAMChemNCAR
# vmrmethanol_CAMChemNCAR
# vmrtoluene_CAMChemNCAR
# vmrbenzene_CAMChemNCAR
# vmrisop_CAMChemNCAR
# vmrtp_CAMChemNCAR
# so4_CAMChemNCAR
# bc_CAMChemNCAR
# poa_CAMChemNCAR
# soa_CAMChemNCAR
# ss_CAMChemNCAR
# dst_CAMChemNCAR
# nh4_CAMChemNCAR
# mmrso4_CAMChemNCAR
# mmrbc_CAMChemNCAR
# mmrpoa_CAMChemNCAR
# mmrsoa_CAMChemNCAR
# mmrss_CAMChemNCAR
# mmrdst_CAMChemNCAR
# mmrnh4_CAMChemNCAR
# vmrco_CAMxAJOU
# vmrhcho_CAMxAJOU
# vmrno_CAMxAJOU
# vmrno2_CAMxAJOU
# vmrno3_CAMxAJOU
# vmrn2o5_CAMxAJOU
# vmrhno4_CAMxAJOU
# vmrhno3_CAMxAJOU
# vmrnh3_CAMxAJOU
# vmrso2_CAMxAJOU
# vmro3_CAMxAJOU
# vmrh2o2_CAMxAJOU
# vmrpan_CAMxAJOU
# vmrorgnit_CAMxAJOU
# vmrhono_CAMxAJOU
# vmrc2h4_CAMxAJOU
# vmralkanes_CAMxAJOU
# vmralkenes_CAMxAJOU
# vmracetone_CAMxAJOU
# vmrglyoxal_CAMxAJOU
# vmrmethanol_CAMxAJOU
# vmrtoluene_CAMxAJOU
# vmrbenzene_CAMxAJOU
# vmraro_CAMxAJOU
# vmrisop_CAMxAJOU
# vmrtp_CAMxAJOU
# mmrno3_CAMxAJOU
# mmrnh4_CAMxAJOU
# mmrso4_CAMxAJOU
# mmrpoa_CAMxAJOU
# mmrsoa_CAMxAJOU
# mmrbc_CAMxAJOU
# mmrdust_CAMxAJOU
# mmrss_CAMxAJOU
# vmrno_WRFChemNCAR
# vmro3_WRFChemNCAR
# vmrno2_WRFChemNCAR
# vmrco_WRFChemNCAR
# vmrhcho_WRFChemNCAR
# vmrso2_WRFChemNCAR
# vmrpan_WRFChemNCAR
# vmrhno3_WRFChemNCAR
# vmrisop_WRFChemNCAR
# vmrch3oh_WRFChemNCAR
# vmrtol_WRFChemNCAR
# vmrch3cho_WRFChemNCAR
# vmrmek_WRFChemNCAR
# vmrgly_WRFChemNCAR
# vmrc2h4_WRFChemNCAR
# vmrbigene_WRFChemNCAR
# vmrbenzene_WRFChemNCAR
# vmrxylene_WRFChemNCAR
# vmrapin_WRFChemNCAR
# vmrbpin_WRFChemNCAR
# vmrbigalk_WRFChemNCAR
# vmrc2h6_WRFChemNCAR
# vmrc3h8_WRFChemNCAR
# so4_WRFChemNCAR
# nit_WRFChemNCAR
# nh4_WRFChemNCAR
# jo1d_WRFChemNCAR
# jno2_WRFChemNCAR
# landmask_WRFChemNCAR
# bc_WRFChemNCAR
# poa_WRFChemNCAR
# soa_WRFChemNCAR
# ssalt_WRFChemNCAR
# vmroh_WRFChemNCAR
# vmrn2o5_WRFChemNCAR
# vmrh2o2_WRFChemNCAR
# vmrhno2_WRFChemNCAR
# vmrnh3_WRFChemNCAR
# vmronit_WRFChemNCAR
# uwnd_WRFChemNCAR
# vwnd_WRFChemNCAR
# pres_WRFChemNCAR
# tmp_WRFChemNCAR
# rh_WRFChemNCAR
# tpot_WRFChemNCAR
# pbl_WRFChemNCAR
# hgt_WRFChemNCAR
# ps_WRFChemPNU
# tmp_WRFChemPNU
# uwnd_WRFChemPNU
# vwnd_WRFChemPNU
# rh_WRFChemPNU
# vmro3_WRFChemPNU
# vmrco_WRFChemPNU
# vmrno_WRFChemPNU
# vmrno2_WRFChemPNU
# vmrno3_WRFChemPNU
# vmrhno3_WRFChemPNU
# vmrpan_WRFChemPNU
# vmrorgnit_WRFChemPNU
# vmrhono_WRFChemPNU
# vmrhno4_WRFChemPNU
# vmrn2o5_WRFChemPNU
# vmroh_WRFChemPNU
# vmrh2o2_WRFChemPNU
# vmrho2_WRFChemPNU
# vmrnh3_WRFChemPNU
# vmrso2_WRFChemPNU
# vmrc2h6_WRFChemPNU
# vmrc2h4_WRFChemPNU
# vmrhcho_WRFChemPNU
# vmrch3cho_WRFChemPNU
# vmrglyoxal_WRFChemPNU
# vmrtoluene_WRFChemPNU
# vmrisop_WRFChemPNU
# nitrate_WRFChemPNU
# so4_WRFChemPNU
# bc_WRFChemPNU
# poa_WRFChemPNU
# soa_WRFChemPNU
# nh4_WRFChemPNU
# mmrno3_WRFChemPNU
# mmrso4_WRFChemPNU
# mmrbc_WRFChemPNU
# mmrpoa_WRFChemPNU
# mmrsoa_WRFChemPNU
# mmrnh4_WRFChemPNU
# jno2_WRFChemIOWA
# jo3o1d_WRFChemIOWA
# bc_WRFChemIOWA
# ammonium_WRFChemIOWA
# nitrate_WRFChemIOWA
# poa_WRFChemIOWA
# salt_WRFChemIOWA
# sulfate_WRFChemIOWA
# soa_WRFChemIOWA
# pressure_WRFChemIOWA
# rh_WRFChemIOWA
# temperature_WRFChemIOWA
# u_WRFChemIOWA
# v_WRFChemIOWA
# c10h16_WRFChemIOWA
# c2h4_WRFChemIOWA
# co_WRFChemIOWA
# dms_WRFChemIOWA
# h2o2_WRFChemIOWA
# hcho_WRFChemIOWA
# hno3_WRFChemIOWA
# hno4_WRFChemIOWA
# ho2_WRFChemIOWA
# isoprene_WRFChemIOWA
# n2o5_WRFChemIOWA
# nh3_WRFChemIOWA
# no_WRFChemIOWA
# no2_WRFChemIOWA
# no3_WRFChemIOWA
# o3_WRFChemIOWA
# oh_WRFChemIOWA
# pan_WRFChemIOWA
# so2_WRFChemIOWA
# toluene_WRFChemIOWA
# orgnit_WRFChemIOWA
# pressure_WRFChemUCLA
# temperature_WRFChemUCLA
# rh_WRFChemUCLA
# u_WRFChemUCLA
# v_WRFChemUCLA
# jno2_WRFChemUCLA
# jo3o1d_WRFChemUCLA
# bc_WRFChemUCLA
# ammonium_WRFChemUCLA
# nitrate_WRFChemUCLA
# sulfate_WRFChemUCLA
# poa_WRFChemUCLA
# soa_WRFChemUCLA
# seasalt_fine_WRFChemUCLA
# seasalt_total_WRFChemUCLA
# dust_fine_WRFChemUCLA
# dust_total_WRFChemUCLA
# pm25_dry_WRFChemUCLA
# pm10_WRFChemUCLA
# c2h4_WRFChemUCLA
# co_WRFChemUCLA
# h2o2_WRFChemUCLA
# hcho_WRFChemUCLA
# hno3_WRFChemUCLA
# hno4_WRFChemUCLA
# ho2_WRFChemUCLA
# isoprene_WRFChemUCLA
# n2o5_WRFChemUCLA
# nh3_WRFChemUCLA
# no_WRFChemUCLA
# no2_WRFChemUCLA
# no3_WRFChemUCLA
# o3_WRFChemUCLA
# oh_WRFChemUCLA
# pan_WRFChemUCLA
# so2_WRFChemUCLA
# toluene_WRFChemUCLA
# c2h6_WRFChemUCLA
# hono_WRFChemUCLA
# c3h8_WRFChemUCLA
# alkanes_WRFChemUCLA
# alkenes_WRFChemUCLA
# ch3cho_WRFChemUCLA
# glyoxal_WRFChemUCLA
# aromatics_WRFChemUCLA
# terpenes_WRFChemUCLA
# orgnit_WRFChemUCLA
# temp_CMAQINHA
# pres_CMAQINHA
# watervapor_CMAQINHA
# vmro3_CMAQINHA
# vmrco_CMAQINHA
# vmrno_CMAQINHA
# vmrno2_CMAQINHA
# vmrno3_CMAQINHA
# vmrhno3_CMAQINHA
# vmrpan_CMAQINHA
# vmrntr_CMAQINHA
# vmrhono_CMAQINHA
# vmrn2o5_CMAQINHA
# vmroh_CMAQINHA
# vmrh2o2_CMAQINHA
# vmrho2_CMAQINHA
# vmrnh3_CMAQINHA
# vmrso2_CMAQINHA
# vmretha_CMAQINHA
# vmrpar_CMAQINHA
# vmreth_CMAQINHA
# vmrole_CMAQINHA
# vmriole_CMAQINHA
# vmrform_CMAQINHA
# vmrald2_CMAQINHA
# vmrmgly_CMAQINHA
# vmrtol_CMAQINHA
# vmrbenzene_CMAQINHA
# vmrxyl_CMAQINHA
# vmrisop_CMAQINHA
# vmrterp_CMAQINHA
# sulfate_CMAQINHA
# nitrate_CMAQINHA
# ammonium_CMAQINHA
# bc_CMAQINHA
# poa_CMAQINHA
# soa_CMAQINHA
# seasalt_CMAQINHA
# dust_CMAQINHA
# LAT_df
# LON_df
# ALT_df
# Datetime_df
# Datetime_old_df
# CH4_df
# CO2_df
# CO_df
# O3_df
# Ethane
# DMS
# CH3Br
# Year_df
# Month_df
# Day_df
# Hour_df
# domain_indicator_df
# Pressure_-24
# Potential_Temperature_-24
# Temperature_-24
# Rainfall_-24
# Mixing_Depth_-24
# Relative_Humidity_-24
# Specific_Humidity_-24
# Mixing_Ratio_-24
# Terrain_Altitude_-24
# Solar_Radiation_-24
# geometry_-24
# DateTime_-24
# Temperature_C_-24
# Distance_ptp_-24
# Cumulative_Dist_-24
# Dist_from_origin_-24
# bearings_from_origin_-24
# bearings_ptp_-24
# Moisture_Flux_-24
# Pressure_-23
# Potential_Temperature_-23
# Temperature_-23
# Rainfall_-23
# Mixing_Depth_-23
# Relative_Humidity_-23
# Specific_Humidity_-23
# Mixing_Ratio_-23
# Terrain_Altitude_-23
# Solar_Radiation_-23
# geometry_-23
# DateTime_-23
# Temperature_C_-23
# Distance_ptp_-23
# Cumulative_Dist_-23
# Dist_from_origin_-23
# bearings_from_origin_-23
# bearings_ptp_-23
# Moisture_Flux_-23
# Pressure_-22
# Potential_Temperature_-22
# Temperature_-22
# Rainfall_-22
# Mixing_Depth_-22
# Relative_Humidity_-22
# Specific_Humidity_-22
# Mixing_Ratio_-22
# Terrain_Altitude_-22
# Solar_Radiation_-22
# geometry_-22
# DateTime_-22
# Temperature_C_-22
# Distance_ptp_-22
# Cumulative_Dist_-22
# Dist_from_origin_-22
# bearings_from_origin_-22
# bearings_ptp_-22
# Moisture_Flux_-22
# Pressure_-21
# Potential_Temperature_-21
# Temperature_-21
# Rainfall_-21
# Mixing_Depth_-21
# Relative_Humidity_-21
# Specific_Humidity_-21
# Mixing_Ratio_-21
# Terrain_Altitude_-21
# Solar_Radiation_-21
# geometry_-21
# DateTime_-21
# Temperature_C_-21
# Distance_ptp_-21
# Cumulative_Dist_-21
# Dist_from_origin_-21
# bearings_from_origin_-21
# bearings_ptp_-21
# Moisture_Flux_-21
# Pressure_-20
# Potential_Temperature_-20
# Temperature_-20
# Rainfall_-20
# Mixing_Depth_-20
# Relative_Humidity_-20
# Specific_Humidity_-20
# Mixing_Ratio_-20
# Terrain_Altitude_-20
# Solar_Radiation_-20
# geometry_-20
# DateTime_-20
# Temperature_C_-20
# Distance_ptp_-20
# Cumulative_Dist_-20
# Dist_from_origin_-20
# bearings_from_origin_-20
# bearings_ptp_-20
# Moisture_Flux_-20
# Pressure_-19
# Potential_Temperature_-19
# Temperature_-19
# Rainfall_-19
# Mixing_Depth_-19
# Relative_Humidity_-19
# Specific_Humidity_-19
# Mixing_Ratio_-19
# Terrain_Altitude_-19
# Solar_Radiation_-19
# geometry_-19
# DateTime_-19
# Temperature_C_-19
# Distance_ptp_-19
# Cumulative_Dist_-19
# Dist_from_origin_-19
# bearings_from_origin_-19
# bearings_ptp_-19
# Moisture_Flux_-19
# Pressure_-18
# Potential_Temperature_-18
# Temperature_-18
# Rainfall_-18
# Mixing_Depth_-18
# Relative_Humidity_-18
# Specific_Humidity_-18
# Mixing_Ratio_-18
# Terrain_Altitude_-18
# Solar_Radiation_-18
# geometry_-18
# DateTime_-18
# Temperature_C_-18
# Distance_ptp_-18
# Cumulative_Dist_-18
# Dist_from_origin_-18
# bearings_from_origin_-18
# bearings_ptp_-18
# Moisture_Flux_-18
# Pressure_-17
# Potential_Temperature_-17
# Temperature_-17
# Rainfall_-17
# Mixing_Depth_-17
# Relative_Humidity_-17
# Specific_Humidity_-17
# Mixing_Ratio_-17
# Terrain_Altitude_-17
# Solar_Radiation_-17
# geometry_-17
# DateTime_-17
# Temperature_C_-17
# Distance_ptp_-17
# Cumulative_Dist_-17
# Dist_from_origin_-17
# bearings_from_origin_-17
# bearings_ptp_-17
# Moisture_Flux_-17
# Pressure_-16
# Potential_Temperature_-16
# Temperature_-16
# Rainfall_-16
# Mixing_Depth_-16
# Relative_Humidity_-16
# Specific_Humidity_-16
# Mixing_Ratio_-16
# Terrain_Altitude_-16
# Solar_Radiation_-16
# geometry_-16
# DateTime_-16
# Temperature_C_-16
# Distance_ptp_-16
# Cumulative_Dist_-16
# Dist_from_origin_-16
# bearings_from_origin_-16
# bearings_ptp_-16
# Moisture_Flux_-16
# Pressure_-15
# Potential_Temperature_-15
# Temperature_-15
# Rainfall_-15
# Mixing_Depth_-15
# Relative_Humidity_-15
# Specific_Humidity_-15
# Mixing_Ratio_-15
# Terrain_Altitude_-15
# Solar_Radiation_-15
# geometry_-15
# DateTime_-15
# Temperature_C_-15
# Distance_ptp_-15
# Cumulative_Dist_-15
# Dist_from_origin_-15
# bearings_from_origin_-15
# bearings_ptp_-15
# Moisture_Flux_-15
# Pressure_-14
# Potential_Temperature_-14
# Temperature_-14
# Rainfall_-14
# Mixing_Depth_-14
# Relative_Humidity_-14
# Specific_Humidity_-14
# Mixing_Ratio_-14
# Terrain_Altitude_-14
# Solar_Radiation_-14
# geometry_-14
# DateTime_-14
# Temperature_C_-14
# Distance_ptp_-14
# Cumulative_Dist_-14
# Dist_from_origin_-14
# bearings_from_origin_-14
# bearings_ptp_-14
# Moisture_Flux_-14
# Pressure_-13
# Potential_Temperature_-13
# Temperature_-13
# Rainfall_-13
# Mixing_Depth_-13
# Relative_Humidity_-13
# Specific_Humidity_-13
# Mixing_Ratio_-13
# Terrain_Altitude_-13
# Solar_Radiation_-13
# geometry_-13
# DateTime_-13
# Temperature_C_-13
# Distance_ptp_-13
# Cumulative_Dist_-13
# Dist_from_origin_-13
# bearings_from_origin_-13
# bearings_ptp_-13
# Moisture_Flux_-13
# Pressure_-12
# Potential_Temperature_-12
# Temperature_-12
# Rainfall_-12
# Mixing_Depth_-12
# Relative_Humidity_-12
# Specific_Humidity_-12
# Mixing_Ratio_-12
# Terrain_Altitude_-12
# Solar_Radiation_-12
# geometry_-12
# DateTime_-12
# Temperature_C_-12
# Distance_ptp_-12
# Cumulative_Dist_-12
# Dist_from_origin_-12
# bearings_from_origin_-12
# bearings_ptp_-12
# Moisture_Flux_-12
# Pressure_-11
# Potential_Temperature_-11
# Temperature_-11
# Rainfall_-11
# Mixing_Depth_-11
# Relative_Humidity_-11
# Specific_Humidity_-11
# Mixing_Ratio_-11
# Terrain_Altitude_-11
# Solar_Radiation_-11
# geometry_-11
# DateTime_-11
# Temperature_C_-11
# Distance_ptp_-11
# Cumulative_Dist_-11
# Dist_from_origin_-11
# bearings_from_origin_-11
# bearings_ptp_-11
# Moisture_Flux_-11
# Pressure_-10
# Potential_Temperature_-10
# Temperature_-10
# Rainfall_-10
# Mixing_Depth_-10
# Relative_Humidity_-10
# Specific_Humidity_-10
# Mixing_Ratio_-10
# Terrain_Altitude_-10
# Solar_Radiation_-10
# geometry_-10
# DateTime_-10
# Temperature_C_-10
# Distance_ptp_-10
# Cumulative_Dist_-10
# Dist_from_origin_-10
# bearings_from_origin_-10
# bearings_ptp_-10
# Moisture_Flux_-10
# Pressure_-9
# Potential_Temperature_-9
# Temperature_-9
# Rainfall_-9
# Mixing_Depth_-9
# Relative_Humidity_-9
# Specific_Humidity_-9
# Mixing_Ratio_-9
# Terrain_Altitude_-9
# Solar_Radiation_-9
# geometry_-9
# DateTime_-9
# Temperature_C_-9
# Distance_ptp_-9
# Cumulative_Dist_-9
# Dist_from_origin_-9
# bearings_from_origin_-9
# bearings_ptp_-9
# Moisture_Flux_-9
# Pressure_-8
# Potential_Temperature_-8
# Temperature_-8
# Rainfall_-8
# Mixing_Depth_-8
# Relative_Humidity_-8
# Specific_Humidity_-8
# Mixing_Ratio_-8
# Terrain_Altitude_-8
# Solar_Radiation_-8
# geometry_-8
# DateTime_-8
# Temperature_C_-8
# Distance_ptp_-8
# Cumulative_Dist_-8
# Dist_from_origin_-8
# bearings_from_origin_-8
# bearings_ptp_-8
# Moisture_Flux_-8
# Pressure_-7
# Potential_Temperature_-7
# Temperature_-7
# Rainfall_-7
# Mixing_Depth_-7
# Relative_Humidity_-7
# Specific_Humidity_-7
# Mixing_Ratio_-7
# Terrain_Altitude_-7
# Solar_Radiation_-7
# geometry_-7
# DateTime_-7
# Temperature_C_-7
# Distance_ptp_-7
# Cumulative_Dist_-7
# Dist_from_origin_-7
# bearings_from_origin_-7
# bearings_ptp_-7
# Moisture_Flux_-7
# Pressure_-6
# Potential_Temperature_-6
# Temperature_-6
# Rainfall_-6
# Mixing_Depth_-6
# Relative_Humidity_-6
# Specific_Humidity_-6
# Mixing_Ratio_-6
# Terrain_Altitude_-6
# Solar_Radiation_-6
# geometry_-6
# DateTime_-6
# Temperature_C_-6
# Distance_ptp_-6
# Cumulative_Dist_-6
# Dist_from_origin_-6
# bearings_from_origin_-6
# bearings_ptp_-6
# Moisture_Flux_-6
# Pressure_-5
# Potential_Temperature_-5
# Temperature_-5
# Rainfall_-5
# Mixing_Depth_-5
# Relative_Humidity_-5
# Specific_Humidity_-5
# Mixing_Ratio_-5
# Terrain_Altitude_-5
# Solar_Radiation_-5
# geometry_-5
# DateTime_-5
# Temperature_C_-5
# Distance_ptp_-5
# Cumulative_Dist_-5
# Dist_from_origin_-5
# bearings_from_origin_-5
# bearings_ptp_-5
# Moisture_Flux_-5
# Pressure_-4
# Potential_Temperature_-4
# Temperature_-4
# Rainfall_-4
# Mixing_Depth_-4
# Relative_Humidity_-4
# Specific_Humidity_-4
# Mixing_Ratio_-4
# Terrain_Altitude_-4
# Solar_Radiation_-4
# geometry_-4
# DateTime_-4
# Temperature_C_-4
# Distance_ptp_-4
# Cumulative_Dist_-4
# Dist_from_origin_-4
# bearings_from_origin_-4
# bearings_ptp_-4
# Moisture_Flux_-4
# Pressure_-3
# Potential_Temperature_-3
# Temperature_-3
# Rainfall_-3
# Mixing_Depth_-3
# Relative_Humidity_-3
# Specific_Humidity_-3
# Mixing_Ratio_-3
# Terrain_Altitude_-3
# Solar_Radiation_-3
# geometry_-3
# DateTime_-3
# Temperature_C_-3
# Distance_ptp_-3
# Cumulative_Dist_-3
# Dist_from_origin_-3
# bearings_from_origin_-3
# bearings_ptp_-3
# Moisture_Flux_-3
# Pressure_-2
# Potential_Temperature_-2
# Temperature_-2
# Rainfall_-2
# Mixing_Depth_-2
# Relative_Humidity_-2
# Specific_Humidity_-2
# Mixing_Ratio_-2
# Terrain_Altitude_-2
# Solar_Radiation_-2
# geometry_-2
# DateTime_-2
# Temperature_C_-2
# Distance_ptp_-2
# Cumulative_Dist_-2
# Dist_from_origin_-2
# bearings_from_origin_-2
# bearings_ptp_-2
# Moisture_Flux_-2
# Pressure_-1
# Potential_Temperature_-1
# Temperature_-1
# Rainfall_-1
# Mixing_Depth_-1
# Relative_Humidity_-1
# Specific_Humidity_-1
# Mixing_Ratio_-1
# Terrain_Altitude_-1
# Solar_Radiation_-1
# geometry_-1
# DateTime_-1
# Temperature_C_-1
# Distance_ptp_-1
# Cumulative_Dist_-1
# Dist_from_origin_-1
# bearings_from_origin_-1
# bearings_ptp_-1
# Moisture_Flux_-1
# Pressure_0
# Potential_Temperature_0
# Temperature_0
# Rainfall_0
# Mixing_Depth_0
# Relative_Humidity_0
# Specific_Humidity_0
# Mixing_Ratio_0
# Terrain_Altitude_0
# Solar_Radiation_0
# geometry_0
# DateTime_0
# Temperature_C_0
# Distance_ptp_0
# Cumulative_Dist_0
# Dist_from_origin_0
# bearings_from_origin_0
# bearings_ptp_0
# Moisture_Flux_0
# Longitude_-24
# Latitude_-24
# AltP_meters_-24
# Longitude_-23
# Latitude_-23
# AltP_meters_-23
# Longitude_-22
# Latitude_-22
# AltP_meters_-22
# Longitude_-21
# Latitude_-21
# AltP_meters_-21
# Longitude_-20
# Latitude_-20
# AltP_meters_-20
# Longitude_-19
# Latitude_-19
# AltP_meters_-19
# Longitude_-18
# Latitude_-18
# AltP_meters_-18
# Longitude_-17
# Latitude_-17
# AltP_meters_-17
# Longitude_-16
# Latitude_-16
# AltP_meters_-16
# Longitude_-15
# Latitude_-15
# AltP_meters_-15
# Longitude_-14
# Latitude_-14
# AltP_meters_-14
# Longitude_-13
# Latitude_-13
# AltP_meters_-13
# Longitude_-12
# Latitude_-12
# AltP_meters_-12
# Longitude_-11
# Latitude_-11
# AltP_meters_-11
# Longitude_-10
# Latitude_-10
# AltP_meters_-10
# Longitude_-9
# Latitude_-9
# AltP_meters_-9
# Longitude_-8
# Latitude_-8
# AltP_meters_-8
# Longitude_-7
# Latitude_-7
# AltP_meters_-7
# Longitude_-6
# Latitude_-6
# AltP_meters_-6
# Longitude_-5
# Latitude_-5
# AltP_meters_-5
# Longitude_-4
# Latitude_-4
# AltP_meters_-4
# Longitude_-3
# Latitude_-3
# AltP_meters_-3
# Longitude_-2
# Latitude_-2
# AltP_meters_-2
# Longitude_-1
# Latitude_-1
# AltP_meters_-1
# Longitude_0
# Latitude_0
# AltP_meters_0
# lat_lon_interaction_0
# lat_diff
# lon_diff
# straight_line_efficiency_ratio
# dew_point_-24
# dew_point_-23
# dew_point_-22
# dew_point_-21
# dew_point_-20
# dew_point_-19
# dew_point_-18
# dew_point_-17
# dew_point_-16
# dew_point_-15
# dew_point_-14
# dew_point_-13
# dew_point_-12
# dew_point_-11
# dew_point_-10
# dew_point_-9
# dew_point_-8
# dew_point_-7
# dew_point_-6
# dew_point_-5
# dew_point_-4
# dew_point_-3
# dew_point_-2
# dew_point_-1
# dew_point_0
# LCL_-24
# LCL_-23
# LCL_-22
# LCL_-21
# LCL_-20
# LCL_-19
# LCL_-18
# LCL_-17
# LCL_-16
# LCL_-15
# LCL_-14
# LCL_-13
# LCL_-12
# LCL_-11
# LCL_-10
# LCL_-9
# LCL_-8
# LCL_-7
# LCL_-6
# LCL_-5
# LCL_-4
# LCL_-3
# LCL_-2
# LCL_-1
# LCL_0
# Rainfall_Estimate_-24
# Rainfall_Estimate_-23
# Rainfall_Estimate_-22
# Rainfall_Estimate_-21
# Rainfall_Estimate_-20
# Rainfall_Estimate_-19
# Rainfall_Estimate_-18
# Rainfall_Estimate_-17
# Rainfall_Estimate_-16
# Rainfall_Estimate_-15
# Rainfall_Estimate_-14
# Rainfall_Estimate_-13
# Rainfall_Estimate_-12
# Rainfall_Estimate_-11
# Rainfall_Estimate_-10
# Rainfall_Estimate_-9
# Rainfall_Estimate_-8
# Rainfall_Estimate_-7
# Rainfall_Estimate_-6
# Rainfall_Estimate_-5
# Rainfall_Estimate_-4
# Rainfall_Estimate_-3
# Rainfall_Estimate_-2
# Rainfall_Estimate_-1
# Rainfall_Estimate_0
# time_difference_-24
# time_difference_seconds_-24
# hour_sin_-24
# hour_cos_-24
# month_sin_-24
# month_cos_-24
# time_difference_-23
# time_difference_seconds_-23
# hour_sin_-23
# hour_cos_-23
# month_sin_-23
# month_cos_-23
# time_difference_-22
# time_difference_seconds_-22
# hour_sin_-22
# hour_cos_-22
# month_sin_-22
# month_cos_-22
# time_difference_-21
# time_difference_seconds_-21
# hour_sin_-21
# hour_cos_-21
# month_sin_-21
# month_cos_-21
# time_difference_-20
# time_difference_seconds_-20
# hour_sin_-20
# hour_cos_-20
# month_sin_-20
# month_cos_-20
# time_difference_-19
# time_difference_seconds_-19
# hour_sin_-19
# hour_cos_-19
# month_sin_-19
# month_cos_-19
# time_difference_-18
# time_difference_seconds_-18
# hour_sin_-18
# hour_cos_-18
# month_sin_-18
# month_cos_-18
# time_difference_-17
# time_difference_seconds_-17
# hour_sin_-17
# hour_cos_-17
# month_sin_-17
# month_cos_-17
# time_difference_-16
# time_difference_seconds_-16
# hour_sin_-16
# hour_cos_-16
# month_sin_-16
# month_cos_-16
# time_difference_-15
# time_difference_seconds_-15
# hour_sin_-15
# hour_cos_-15
# month_sin_-15
# month_cos_-15
# time_difference_-14
# time_difference_seconds_-14
# hour_sin_-14
# hour_cos_-14
# month_sin_-14
# month_cos_-14
# time_difference_-13
# time_difference_seconds_-13
# hour_sin_-13
# hour_cos_-13
# month_sin_-13
# month_cos_-13
# time_difference_-12
# time_difference_seconds_-12
# hour_sin_-12
# hour_cos_-12
# month_sin_-12
# month_cos_-12
# time_difference_-11
# time_difference_seconds_-11
# hour_sin_-11
# hour_cos_-11
# month_sin_-11
# month_cos_-11
# time_difference_-10
# time_difference_seconds_-10
# hour_sin_-10
# hour_cos_-10
# month_sin_-10
# month_cos_-10
# time_difference_-9
# time_difference_seconds_-9
# hour_sin_-9
# hour_cos_-9
# month_sin_-9
# month_cos_-9
# time_difference_-8
# time_difference_seconds_-8
# hour_sin_-8
# hour_cos_-8
# month_sin_-8
# month_cos_-8
# time_difference_-7
# time_difference_seconds_-7
# hour_sin_-7
# hour_cos_-7
# month_sin_-7
# month_cos_-7
# time_difference_-6
# time_difference_seconds_-6
# hour_sin_-6
# hour_cos_-6
# month_sin_-6
# month_cos_-6
# time_difference_-5
# time_difference_seconds_-5
# hour_sin_-5
# hour_cos_-5
# month_sin_-5
# month_cos_-5
# time_difference_-4
# time_difference_seconds_-4
# hour_sin_-4
# hour_cos_-4
# month_sin_-4
# month_cos_-4
# time_difference_-3
# time_difference_seconds_-3
# hour_sin_-3
# hour_cos_-3
# month_sin_-3
# month_cos_-3
# time_difference_-2
# time_difference_seconds_-2
# hour_sin_-2
# hour_cos_-2
# month_sin_-2
# month_cos_-2
# time_difference_-1
# time_difference_seconds_-1
# hour_sin_-1
# hour_cos_-1
# month_sin_-1
# month_cos_-1
# time_difference_0
# time_difference_seconds_0
# hour_sin_0
# hour_cos_0
# month_sin_0
# month_cos_0
# std_pressure
# delta_pressure
# mean_pressure
# sum_pressure
# std_potential_temperature
# delta_potential_temperature
# mean_potential_temperature
# sum_potential_temperature
# std_relative_humidity
# delta_relative_humidity
# mean_relative_humidity
# sum_relative_humidity
# std_specific_humidity
# delta_specific_humidity
# mean_specific_humidity
# sum_specific_humidity
# std_solar_radiation
# delta_solar_radiation
# mean_solar_radiation
# sum_solar_radiation
# std_mixing_depth
# delta_mixing_depth
# mean_mixing_depth
# sum_mixing_depth
# std_moisture_flux
# delta_moisture_flux
# mean_moisture_flux
# sum_moisture_flux
# std_temperature_c
# delta_temperature_c
# mean_temperature_c
# sum_temperature_c
# std_rainfall_estimate
# delta_rainfall_estimate
# mean_rainfall_estimate
# sum_rainfall_estimate
# std_lcl
# delta_lcl
# mean_lcl
# sum_lcl
# std_dew_point
# delta_dew_point
# mean_dew_point
# sum_dew_point
# std_latitude
# delta_latitude
# mean_latitude
# sum_latitude
# std_longitude
# delta_longitude
# mean_longitude
# sum_longitude
# Velocity_-24
# Velocity_-23
# Velocity_-22
# Velocity_-21
# Velocity_-20
# Velocity_-19
# Velocity_-18
# Velocity_-17
# Velocity_-16
# Velocity_-15
# Velocity_-14
# Velocity_-13
# Velocity_-12
# Velocity_-11
# Velocity_-10
# Velocity_-9
# Velocity_-8
# Velocity_-7
# Velocity_-6
# Velocity_-5
# Velocity_-4
# Velocity_-3
# Velocity_-2
# Velocity_-1
# std_velocity
# delta_velocity
# mean_velocity
# domain_label
# spatial_cluster
# kfold_Longitude
# kfold_cluster
# min_distance_to_cluster_centroids
# mean_distance_to_cluster_centroids
# min_distance_to_t1000_cities
# mean_distance_to_t1000_cities
# min_distance_to_extent_corners
# mean_distance_to_extent_corners
# min_distance_to_antimeridian
# mean_distance_to_antimeridian
# PASTEL_CO
# PASTEL_CH4
# PASTEL_Ethane
# PASTEL_DMS
# PASTEL_CH3Br
# PASTEL_O3

# %%
korusaq_f["vmrc2h6_GEOSChemSNU"] = korusaq_f["vmrc2h6_GEOSChemSNU"] * 1e3
korusaq_f["vmrc2h6_CAMChemNCAR"] = korusaq_f["vmrc2h6_CAMChemNCAR"] * 1e3
korusaq_f["vmrc2h6_WRFChemNCAR"] = korusaq_f["vmrc2h6_WRFChemNCAR"] * 1e3
korusaq_f["vmrc2h6_WRFChemPNU"] = korusaq_f["vmrc2h6_WRFChemPNU"] * 1e3
korusaq_f["c2h6_WRFChemUCLA"] = korusaq_f["c2h6_WRFChemUCLA"] * 1e3

# %%
ATS_names = ["CO", "CH4", "CH3Br", "DMS", "O3", "Ethane"]

# Create a mapping of names to specific column names for the GMI and PASTEL models
model_mapping = {
    "CO": [
        ("CO_df", "vmrco_GEOSChemSNU", "PASTEL_CO"),
        ("CO_df", "vmrco_CAMChemNCAR", "PASTEL_CO"),
        ("CO_df", "vmrco_WRFChemNCAR", "PASTEL_CO"),
        ("CO_df", "vmrco_WRFChemPNU", "PASTEL_CO"),
        ("CO_df", "co_WRFChemIOWA", "PASTEL_CO"),
        ("CO_df", "co_WRFChemUCLA", "PASTEL_CO"),
        ("CO_df", "vmrco_CMAQINHA", "PASTEL_CO"),
    ],
    "Ethane": [
        ("Ethane", "vmrc2h6_GEOSChemSNU", "PASTEL_Ethane"),
        ("Ethane", "vmrc2h6_CAMChemNCAR", "PASTEL_Ethane"),
        ("Ethane", "vmrc2h6_WRFChemNCAR", "PASTEL_Ethane"),
        ("Ethane", "vmrc2h6_WRFChemPNU", "PASTEL_Ethane"),
        ("Ethane", "c2h6_WRFChemUCLA", "PASTEL_Ethane"),
    ],
    "O3": [
        ("O3_df", "vmrco_GEOSChemSNU", "PASTEL_O3"),
        ("O3_df", "vmro3_CAMChemNCAR", "PASTEL_O3"),
        ("O3_df", "vmro3_CAMxAJOU", "PASTEL_O3"),
        ("O3_df", "vmro3_WRFChemNCAR", "PASTEL_O3"),
        ("O3_df", "vmro3_WRFChemPNU", "PASTEL_O3"),
        ("O3_df", "o3_WRFChemIOWA", "PASTEL_O3"),
        ("O3_df", "o3_WRFChemUCLA", "PASTEL_O3"),
        ("O3_df", "vmro3_CMAQINHA", "PASTEL_O3"),
    ],
    "CH4": [],
    "CH3Br": [],
    "DMS": [],
}


save_path = r"C:\Users\vwgei\Documents\PVOCAL\plots\model_plots\korusaq_micp"

# Initialize an empty list to store results
metrics_list = []

# Loop through species and calculate metrics
for species, models in model_mapping.items():
    for data_col, korusaq_col, pastel_col in models:
        # Drop NaN values from both data and target columns
        merged_korusaq = pd.concat([korusaq_f[data_col], korusaq_f[korusaq_col]], axis=1).dropna()

        merged_korusaq = merged_korusaq[merged_korusaq[korusaq_col] > 0]

        merged_pastel = pd.concat([korusaq_f[data_col], korusaq_f[pastel_col]], axis=1).dropna()

        # Ensure the same rows are kept in both DataFrames (i.e., intersection of indexes)
        merged_korusaq = merged_korusaq.loc[merged_korusaq.index.intersection(merged_pastel.index)]

        save_path = rf"C:\Users\vwgei\Documents\PVOCAL\plots\model_plots\korusaq_micp\{korusaq_col}{species}.png"
        
        scatter_plot(merged_korusaq[data_col], merged_korusaq[korusaq_col], f"{korusaq_col}_scatter", species, save_path)

        print(len(merged_korusaq))

        # Calculate metrics for GMI and PASTEL after dropping NaN
        metrics_list.append(
            calculate_and_organize_metrics_model(merged_korusaq[data_col], merged_korusaq[korusaq_col], korusaq_col, species)
        )
    save_path = rf"C:\Users\vwgei\Documents\PVOCAL\plots\model_plots\korusaq_micp\{pastel_col}{species}.png"
    scatter_plot(merged_pastel[data_col], merged_pastel[pastel_col], "pastel_sctter", species, save_path)
    metrics_list.append(
        calculate_and_organize_metrics_model(merged_pastel[data_col], merged_pastel[pastel_col], "PASTEL", species)
    )

# Combine all metrics into a single DataFrame
model_metrics = pd.concat(metrics_list, ignore_index=True)

model_metrics[['Model', 'ATS', 'RMSE', 'MAE', "R2"]]
# Out:
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# 538
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# 493
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# 467
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# 493
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# 483
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# 483
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# 529
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# 572
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# 512
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# 488
# 512
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# 499
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# 533
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# 487
# 533
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# 464
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# 487
# 479
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:70: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig,ax = plt.subplots(figsize=(8, 6))
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# 479
# 526
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
# C:\Users\vwgei\AppData\Local\Temp\ipykernel_11824\1244472152.py:71: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(actual, pred, edgecolors=(0,0,0), c=color, cmap=cm)
#                   Model     ATS         RMSE         MAE         R2
# 0     vmrco_GEOSChemSNU      CO   130.464716   76.362595   0.127361
# 1     vmrco_CAMChemNCAR      CO   141.920862  101.846874  -0.265422
# 2     vmrco_WRFChemNCAR      CO   128.963760   86.445120  -0.025462
# 3      vmrco_WRFChemPNU      CO   141.367671   98.485912  -0.255576
# 4        co_WRFChemIOWA      CO   105.632340   62.648415   0.308081
# 5        co_WRFChemUCLA      CO   101.010255   61.313548   0.367308
# 6        vmrco_CMAQINHA      CO   125.387981   66.874801   0.204665
# 7                PASTEL      CO   189.016055  134.969085  -0.840585
# 8   vmrc2h6_GEOSChemSNU  Ethane   868.491597  603.667572   0.018580
# 9   vmrc2h6_CAMChemNCAR  Ethane  1043.368363  865.827833  -0.761696
# 10  vmrc2h6_WRFChemNCAR  Ethane  1210.493404  850.271328  -1.302908
# 11   vmrc2h6_WRFChemPNU  Ethane   934.047118  735.097051  -0.411865
# 12     c2h6_WRFChemUCLA  Ethane   741.532281  465.461725   0.127036
# 13               PASTEL  Ethane  1295.360659  941.156185  -1.183864
# 14    vmrco_GEOSChemSNU      O3   108.027013   88.001782 -23.417578
# 15    vmro3_CAMChemNCAR      O3    20.663832   14.866043   0.016223
# 16       vmro3_CAMxAJOU      O3    26.227058   20.648987  -0.439253
# 17    vmro3_WRFChemNCAR      O3    20.223478   14.104898   0.011989
# 18     vmro3_WRFChemPNU      O3    28.930156   24.016645  -0.928308
# 19       o3_WRFChemIOWA      O3    19.623827   14.986698   0.124779
# 20       o3_WRFChemUCLA      O3    20.339106   15.612973   0.059813
# 21       vmro3_CMAQINHA      O3    25.880898   18.203673  -0.403491
# 22               PASTEL      O3    36.096751   27.320644  -1.726303
# 23               PASTEL     CH4    36.096751   27.320644  -1.726303
# 24               PASTEL   CH3Br    36.096751   27.320644  -1.726303
# 25               PASTEL     DMS    36.096751   27.320644  -1.726303

# %%
print(data_col, korusaq_col, pastel_col)
# Out:
# O3_df vmro3_CMAQINHA PASTEL_O3

# %%
# #ALL of CO
# # Open the file in binary read mode and load the object
# with open(r"C:\Users\vwgei\Documents\PVOCAL\ensemble_working\global_models\V4_CO\data\CO_global_X_train.pkl", 'rb') as file:
#     co_train = pickle.load(file)
# with open(r"C:\Users\vwgei\Documents\PVOCAL\ensemble_working\global_models\V4_CO\data\CO_global_X_test.pkl", 'rb') as file:
#     co_test = pickle.load(file)
# co_pred_train = np.load(r"C:\Users\vwgei\Documents\PVOCAL\ensemble_working\PASTEL_combined\V4_CO\CO_PASTEL_combined_pred_train.npy")
# co_pred_test = np.load(r"C:\Users\vwgei\Documents\PVOCAL\ensemble_working\PASTEL_combined\V4_CO\CO_PASTEL_combined_pred_test.npy")

# co_train['CO_PASTEL'] = co_pred_train
# co_test['CO_PASTEL'] = co_pred_test

# matching_rows = atom_gmi[atom_gmi['iindex'].isin(co_test.index)]
# matching_rows = matching_rows.set_index('iindex')

# # Find the intersection of the indexes
# matching_indexes = co_test.index.intersection(matching_rows.index)

# # Filter the DataFrames to keep only rows with the matching indexes
# var_test_matched = co_test.loc[matching_indexes]
# matching_rows_matched = matching_rows.loc[matching_indexes]

# merged = pd.concat([var_test_matched, matching_rows_matched], axis=1)

# matching_rows = df[df['iindex'].isin(merged.index)]
# matching_rows = matching_rows.set_index('iindex')

# # Find the intersection of the indexes
# matching_indexes = merged.index.intersection(matching_rows.index)

# # Filter the DataFrames to keep only rows with the matching indexes
# var_test_matched = merged.loc[matching_indexes]
# matching_rows_matched = matching_rows.loc[matching_indexes]

# final_merged = pd.concat([var_test_matched, matching_rows_matched], axis=1)

# gmi_co = calculate_and_organize_metrics_model(final_merged.iloc[:, 1], final_merged['GMI_CO_GMI'], "ATom_GMI", "CO")

# # make the final model_metrics df the first time
# model_metrics = calculate_and_organize_metrics_model(final_merged.iloc[:, 1], final_merged['CO_PASTEL'], "PASTEL_ATOM_GMI", "CO")

# model_metrics = pd.concat([model_metrics, gmi_co], ignore_index=True)

# model_metrics
# ########################################################################################


# # matching_rows = atom_cesm[atom_cesm['iindex'].isin(co_test.index)]
# # matching_rows = matching_rows.set_index('iindex')

# # # Find the intersection of the indexes
# # matching_indexes = co_test.index.intersection(matching_rows.index)

# # # Filter the DataFrames to keep only rows with the matching indexes
# # var_test_matched = co_test.loc[matching_indexes]
# # matching_rows_matched = matching_rows.loc[matching_indexes]

# # merged = pd.concat([var_test_matched, matching_rows_matched], axis=1)

# # cesm_co = calculate_and_organize_metrics_model(merged['CO'], merged['CO_CESM'], "ATom_CESM", "CO")

# # # make the final model_metrics df the first time
# # pastel_cesm_co = calculate_and_organize_metrics_model(merged['CO'], merged['CO_PASTEL'], "PASTEL_ATOM_CESM", "CO")

# # model_metrics = pd.concat([model_metrics, cesm_co, pastel_cesm_co], ignore_index=True)


# # matching_rows = seac4rs[seac4rs['iindex'].isin(co_test.index)]
# # matching_rows = matching_rows.set_index('iindex')

# # # Find the intersection of the indexes
# # matching_indexes = co_test.index.intersection(matching_rows.index)

# # # Filter the DataFrames to keep only rows with the matching indexes
# # var_test_matched = co_test.loc[matching_indexes]
# # matching_rows_matched = matching_rows.loc[matching_indexes]

# # merged = pd.concat([var_test_matched, matching_rows_matched], axis=1)

# # seac4rs_co = calculate_and_organize_metrics_model(merged['CO'], merged['CO_geos-chem'], "SEAC4RS_GEOS-Chem", "CO")

# # # make the final model_metrics df the first time
# # pastel_seac4rs_co = calculate_and_organize_metrics_model(merged['CO'], merged['CO_PASTEL'], "PASTEL_SEAC4RS", "CO")

# # model_metrics = pd.concat([model_metrics, seac4rs_co, pastel_seac4rs_co], ignore_index=True)


# # matching_rows = winter[winter['iindex'].isin(co_test.index)]
# # matching_rows = matching_rows.set_index('iindex')

# # # Find the intersection of the indexes
# # matching_indexes = co_test.index.intersection(matching_rows.index)

# # # Filter the DataFrames to keep only rows with the matching indexes
# # var_test_matched = co_test.loc[matching_indexes]
# # matching_rows_matched = matching_rows.loc[matching_indexes]

# # merged = pd.concat([var_test_matched, matching_rows_matched], axis=1)

# # winter_co = calculate_and_organize_metrics_model(merged['CO'], merged['CO_geos-chem'], "SEAC4RS_GEOS-Chem", "CO")

# # # make the final model_metrics df the first time
# # pastel_winter_co = calculate_and_organize_metrics_model(merged['CO'], merged['CO_PASTEL'], "PASTEL_SEAC4RS", "CO")

# # model_metrics = pd.concat([model_metrics, winter_co, pastel_winter_co], ignore_index=True)
